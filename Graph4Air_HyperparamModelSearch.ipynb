# %% [markdown]
# # Hyperparameter Tuning Workflow
#
# This notebook performs end-to-end hyperparameter optimization for GCN and GAT models predicting NO₂ on road segments. It is organized into:
#
# ## Contents
#
# 1. **Environment Setup**
#    Install and configure PyTorch-Geometric, Optuna, and other dependencies.
#    _Code block 1_
#
# 2. **Core Imports & Drive Mount**
#    Import data, geospatial, graph, ML, plotting, and GNN libraries; mount Google Drive.
#    _Code block 2_
#
# 3. **Data Preparation & Graph Construction**
#    - Load road-network GeoJSON; compute centroids & feature matrix.
#    - Build spatial NetworkX graph of touching segments.
#    _First part of Code block 3_
#
# 4. **Outlier Detection**
#    Identify spatial outliers in NO₂ by 1-hop neighbor residuals with MAD thresholds.
#    _Middle of Code block 3_
#
# 5. **Graph Augmentation & Data Builder**
#    - Add far-range “feature_sim” edges via grouped KNN & spatial filters.
#    - Create `torch_geometric.data.Data` objects with train/test masks (dropping outliers).
#    _Second half of Code block 3_
#
# 6. **Optuna Hyperparameter Tuning**
#    Use Tree-structured Parzen Estimator + Hyperband pruning to optimize GCN & GAT hyperparameters:
#    layers, hidden size, dropout, learning rate, weight decay, activation.
#    _Last part of Code block 3_
#
# 7. **Results**
#    Print best hyperparameters for GCN and GAT.
#    _End of Code block 3_
#
# > **Tip:** Run each section in order to reproduce the full optimization pipeline.

# %% [markdown]
# ### 1. Environment Setup
#
# Installs Optuna and the matching PyTorch-Geometric wheels for your current PyTorch version so you can run GNNs and hyperparameter searches.

# %%
# Ensure we have the correct PyTorch version for PyG wheels
import torch

# !pip install optuna -q
# !pip uninstall torch-scatter torch-sparse torch-geometric torch-cluster --y -q
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-{torch.__version__}.html -q
# !pip install torch-sparse  -f https://data.pyg.org/whl/torch-{torch.__version__}.html -q
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-{torch.__version__}.html -q
# !pip install git+https://github.com/pyg-team/pytorch_geometric.git -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 7.7 MB/s eta 0:00:00
# WARNING: Skipping torch-scatter as it is not installed.
# WARNING: Skipping torch-sparse as it is not installed.
# WARNING: Skipping torch-geometric as it is not installed.
# WARNING: Skipping torch-cluster as it is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 26.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 44.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done

# %% [markdown]
# ### 2. Core Imports & Drive Mount
#
# Loads all required Python packages for data I/O, geospatial processing, graph operations, ML metrics, plotting, and GNN layers, then mounts Google Drive for easy data access.

# %%
# data & geospatial
import numpy as np
import pandas as pd
import geopandas as gpd
import os

# graph handling
import networkx as nx

# scikit-learn utilities
from sklearn.neighbors    import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from sklearn.metrics       import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
from scipy.stats           import pearsonr

# progress bars
from tqdm.auto import tqdm

# miscellaneous
import random
from collections import Counter

# plotting
import matplotlib.pyplot as plt

# PyTorch & PyTorch-Geometric
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.utils import from_networkx
from torch_geometric.data  import Data
from torch_geometric.nn    import GCNConv, GATConv

# Optuna for hyperparameter search
import optuna
from optuna.samplers import TPESampler
from optuna.pruners  import HyperbandPruner

# Mount Google Drive for data I/O
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 3. Full Hyperparameter Tuning Pipeline
#
# Defines fixed “best” graph-augmentation parameters; loads, preprocesses, and outlier-filters your road-segment data; augments the graph; wraps everything into PyTorch-Geometric `Data` objects; and runs an Optuna study to tune both GCN and GAT models end-to-end.

# %%
# This is the fixed full version of your model hyperparameter tuning setup
# using the best found graph augmentation parameters

# Fixed best augmentation parameters
best_graph_params_1 = {
    'top_n': 1000,
    'neighbors': 120,
    'sim_thresh': 0.9888,
    'min_dist': 197,
    'max_dist': 1152,
    'hop_thresh': 5,
    'max_edges': 3000,
    'per_node_cap': 4
}

best_graph_params_2 = {
    'top_n': 1000,
    'neighbors': 180,
    'sim_thresh': 0.9834,
    'min_dist': 167,
    'max_dist': 1583,
    'hop_thresh': 4,
    'max_edges': 4500,
    'per_node_cap': 2
}

# Data prep
fp = '/content/drive/MyDrive/Universiteit Utrecht/Thesis/data/road_network_lufeature.geojson'
gdf = gpd.read_file(fp).to_crs(epsg=28992).reset_index(drop=True)
gdf['centroid'] = gdf.geometry.centroid
coords = np.column_stack([gdf.centroid.x, gdf.centroid.y])

target_col = 'NO2d'
feature_cols = [c for c in gdf.columns if any(s in c for s in ['AGRI','INDUS','NATUR','PORT','RES','TRANS','URBG','WATER','POP','EEA','HHOLD','RDL','TLOA','HLOA','MRDL','TMLOA','HMLOA','TRAF','DINV'])]
feature_matrix = gdf[feature_cols].to_numpy()

# Graph & outliers
G = nx.Graph()
sidx = gdf.sindex
for idx, row in gdf.iterrows():
    G.add_node(idx, **row.drop('geometry').to_dict())
for idx, geom in enumerate(gdf.geometry):
    for j in sidx.intersection(geom.bounds):
        if idx != j and geom.touches(gdf.geometry[j]):
            G.add_edge(idx, j)

gdf['is_highway'] = gdf['TRAFMAJOR'] > 20000
group_thresh = {True: 9.0, False: 5.0}

def detect_outliers(G, gdf):
    nodes = list(G.nodes())
    vals, neigh_means = [], []
    for n in nodes:
        v = gdf.at[n, target_col]
        if pd.isna(v):
            vals.append(np.nan); neigh_means.append(np.nan)
            continue
        sp = nx.single_source_shortest_path_length(G, n, cutoff=1)
        neigh = [m for m in sp if m != n]
        nbr_vals = gdf.loc[neigh, target_col].dropna().values
        vals.append(v)
        neigh_means.append(np.nan if nbr_vals.size == 0 else nbr_vals.mean())
    vals = np.array(vals); neigh_means = np.array(neigh_means)
    valid = ~np.isnan(vals) & ~np.isnan(neigh_means)
    residuals = vals[valid] - neigh_means[valid]
    valid_nodes = np.array(nodes)[valid]
    med = np.median(residuals)
    mad = np.median(np.abs(residuals - med))
    cutoffs = np.array([
        (group_thresh.get(gdf.at[n, 'is_highway'], 3.0)) * mad for n in valid_nodes
    ])
    is_outlier = np.abs(residuals - med) > cutoffs
    return valid_nodes[is_outlier].tolist()

outliers = detect_outliers(G, gdf)

# ────────────────────────────────────────────────────────────
# 2) Classify outliers: errors vs real extremes
# ────────────────────────────────────────────────────────────
palmes_fp  = '/content/drive/MyDrive/Universiteit Utrecht/Thesis/data/road_palmes_25m.geojson'
palmes_gdf = gpd.read_file(palmes_fp).to_crs(gdf.crs)

hot_thresh = np.percentile(gdf['NO2d'].dropna(), 75)
mask_valid = gdf['NO2d'].notna() & gdf['TRAFNEAR'].notna()
X_tr = gdf.loc[mask_valid, 'TRAFNEAR'].values.reshape(-1,1)
y_tr = gdf.loc[mask_valid, 'NO2d'].values
lr = LinearRegression().fit(X_tr, y_tr)
traffic_rmse = np.sqrt(mean_squared_error(y_tr, lr.predict(X_tr)))

error_segs, real_segs = [], []
for seg in outliers:
    seg_val   = gdf.at[seg, 'NO2d']
    traf_near = gdf.at[seg, 'TRAFNEAR']
    pt        = gdf.geometry[seg]

    # 1) Palmes nearby?
    nearby_pal = palmes_gdf[palmes_gdf.geometry.distance(pt) <= 50]
    if len(nearby_pal):
        pal_val = nearby_pal['mean_annual_palmes_no2'].mean()
        if seg_val > 2 * pal_val:
            error_segs.append(seg)
        else:
            real_segs.append(seg)
        continue

    # 2) Neighbors high?
    nbrs     = list(gdf.sindex.intersection(pt.buffer(200).bounds))
    nbr_vals = gdf.loc[nbrs, 'NO2d'].dropna()
    if len(nbr_vals) and (nbr_vals > hot_thresh).mean() > 0.5:
        real_segs.append(seg)
        continue

    # 3) Traffic prediction
    if not np.isnan(traf_near):
        pred_traf = lr.predict([[traf_near]])[0]
        if abs(seg_val - pred_traf) > 3 * traffic_rmse:
            error_segs.append(seg)
        else:
            real_segs.append(seg)
        continue

    # default
    real_segs.append(seg)

print(f"Classified {len(error_segs)} errors, {len(real_segs)} real extremes.")

# Graph augmentation + Data builder
def augment_grouped_far_knn(G, gdf, groups, coords, feature_matrix, feature_cols,
                            top_n, neighbors, sim_thresh, min_dist, max_dist,
                            hop_thresh, max_edges, per_node_cap,
                            road_id_col="ROAD_FID", suffix='grp_far_knn'):
    road_ids = gdf[road_id_col].to_numpy()
    col_to_idx = {c:i for i,c in enumerate(feature_cols)}
    candidates = set()
    for cols in groups.values():
        if any(c not in col_to_idx for c in cols): continue
        intensity = gdf[cols].sum(axis=1)
        top_idx   = intensity.nlargest(top_n).index.to_numpy()
        if top_idx.size < 2: continue
        idxs = [col_to_idx[c] for c in cols]
        subF = feature_matrix[top_idx][:, idxs]
        subF /= np.linalg.norm(subF, axis=1, keepdims=True).clip(1e-6)
        nbr = NearestNeighbors(n_neighbors=min(neighbors+1, len(top_idx)), metric='cosine', n_jobs=-1).fit(subF)
        dists, nn_idxs = nbr.kneighbors(subF)
        sims = 1 - dists
        for ii, src in enumerate(top_idx):
            close = set(nx.single_source_shortest_path_length(G, int(src), cutoff=hop_thresh))
            for rank, dst_j in enumerate(nn_idxs[ii,1:], start=1):
                if sims[ii, rank] < sim_thresh: break
                dst = top_idx[dst_j]; u, v = sorted((int(src), int(dst)))
                if road_ids[src] == road_ids[dst]: continue
                dxy = np.hypot(*(coords[src] - coords[dst]))
                if dxy < min_dist or dxy > max_dist or dst in close: continue
                candidates.add((u, v))
    final, counts = [], Counter()
    for u, v in random.sample(list(candidates), len(candidates)):
        if counts[u] < per_node_cap and counts[v] < per_node_cap:
            final.append((u, v)); counts[u] += 1; counts[v] += 1
        if len(final) >= max_edges: break
    G2 = G.copy(); G2.add_edges_from(final, feature_sim=suffix)
    return G2, final

def build_data_mask_missing(G, gdf, feature_cols, target_col, outliers=None):
    gdf2 = gdf.reset_index(drop=True)
    G2 = nx.relabel_nodes(G, {old:new for new,old in enumerate(gdf.index)})
    X = StandardScaler().fit_transform(gdf2[feature_cols].values)
    y = gdf2[target_col].values.reshape(-1,1)
    edges = np.array(list(G2.edges())).T
    edge_index = torch.tensor(np.concatenate([edges, edges[::-1]], axis=1), dtype=torch.long)
    data = Data(
        x=torch.tensor(X, dtype=torch.float),
        edge_index=edge_index,
        y=torch.tensor(y, dtype=torch.float)
    )
    valid_idx = np.where(~np.isnan(y.flatten()))[0]
    perm = torch.randperm(len(valid_idx))
    n_train = int(0.8 * len(valid_idx))
    train_idx = valid_idx[perm[:n_train].numpy()]
    test_idx  = valid_idx[perm[n_train:].numpy()]
    train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
    test_mask  = torch.zeros(data.num_nodes, dtype=torch.bool)
    train_mask[train_idx] = True; test_mask[test_idx] = True
    if outliers is not None:
        train_mask[outliers] = False
    data.train_mask = train_mask
    data.test_mask = test_mask
    return data

# Groups used for augmentation
groups = {
    'industrial':        ['INDUS_300','INDUS_1000'],
    'residential':       ['RES_300','RES_1000'],
    'agriculture':       ['AGRI_300','AGRI_1000'],
    'natural':           ['NATUR_300','NATUR_1000'],
    'port':              ['PORT_300','PORT_1000'],
    'urb_built':         ['URBG_300','URBG_1000'],
    'water':             ['WATER_300','WATER_1000'],
    'traffic':           ['TRAFNEAR','TRAFMAJOR'],
    'pop':               ['POP_300','POP_1000'],
    'population_density':['EEA_300','EEA_1000'],
}

# Dynamic model tuning setup
def tune_model(model_cls, graph_params, n_trials=200):
    def objective(trial):
        num_layers = trial.suggest_int('num_layers', 2, 4)
        hidden_units = trial.suggest_categorical('hidden_units', [16, 32, 64])
        dropout = trial.suggest_float('dropout', 0.0, 0.5)
        lr = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
        weight_decay = trial.suggest_float('weight_decay', 1e-5, 1e-3, log=True)
        activation = trial.suggest_categorical('activation', ['relu', 'elu'])

        G_aug, _ = augment_grouped_far_knn(G, gdf, groups, coords, feature_matrix, feature_cols, **graph_params)
        data = build_data_mask_missing(G_aug, gdf, feature_cols, target_col, outliers=error_segs)
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        data = data.to(device)

        model = model_cls(len(feature_cols), hidden_units, 1,
                          num_layers=num_layers, dropout=dropout, activation=activation).to(device)
        opt = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        for _ in range(100):
            model.train(); opt.zero_grad()
            out = model(data.x, data.edge_index)
            loss = F.mse_loss(out[data.train_mask], data.y[data.train_mask])
            loss.backward(); opt.step()
        model.eval()
        with torch.no_grad():
            pred = model(data.x, data.edge_index)[data.test_mask]
            true = data.y[data.test_mask]
            return torch.sqrt(F.mse_loss(pred, true)).item()

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)
    return study

# Define final model classes
class GCN(torch.nn.Module):
    def __init__(self, in_c, h_c, out_c, num_layers=2, dropout=0.0, activation='relu'):
        super().__init__()
        acts = {'relu': F.relu, 'elu': F.elu}; self.activation = acts[activation]
        self.dropout = dropout
        self.layers = torch.nn.ModuleList(
            [GCNConv(in_c, h_c)] + [GCNConv(h_c, h_c) for _ in range(num_layers-2)] + [GCNConv(h_c, out_c)])
    def forward(self, x, edge_index):
        for layer in self.layers[:-1]:
            x = F.dropout(self.activation(layer(x, edge_index)), p=self.dropout, training=self.training)
        return self.layers[-1](x, edge_index)

class GAT(torch.nn.Module):
    def __init__(self, in_c, h_c, out_c, num_layers=2, dropout=0.0, activation='elu', heads=2):
        super().__init__()
        acts = {'relu': F.relu, 'elu': F.elu}; self.activation = acts[activation]
        self.dropout = dropout; self.heads = heads
        self.layers = torch.nn.ModuleList()
        self.layers.append(GATConv(in_c, h_c, heads=heads))
        for _ in range(num_layers - 2):
            self.layers.append(GATConv(h_c*heads, h_c, heads=heads))
        self.out = GATConv(h_c*heads, out_c, heads=1, concat=False)
    def forward(self, x, edge_index):
        for layer in self.layers:
            x = F.dropout(self.activation(layer(x, edge_index)), p=self.dropout, training=self.training)
        return self.out(x, edge_index)

# Run all tuning
print("\nTuning GCN on best graph params set 1")
study_gcn1 = tune_model(GCN, best_graph_params_1)
print("Best GCN1 params:", study_gcn1.best_params)

print("\nTuning GAT on best graph params set 2")
study_gat2 = tune_model(lambda *args, **kwargs: GAT(*args, **kwargs, heads=2), best_graph_params_2)
print("Best GAT2 params:", study_gat2.best_params)
# Out:
# [I 2025-05-28 12:01:39,739] A new study created in memory with name: no-name-9c353112-d614-4ef8-a8ea-7676b6165b81
# Classified 125 errors, 2047 real extremes.
#
# Tuning GCN on best graph params set 1
# [I 2025-05-28 12:02:50,800] Trial 0 finished with value: 10.014951705932617 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06794594729446835, 'learning_rate': 0.0011098520917628392, 'weight_decay': 0.00010131845793380289, 'activation': 'elu'}. Best is trial 0 with value: 10.014951705932617.
# [I 2025-05-28 12:03:34,021] Trial 1 finished with value: 15.754504203796387 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.4605081754398706, 'learning_rate': 0.0004370832660900373, 'weight_decay': 9.552961597986633e-05, 'activation': 'elu'}. Best is trial 0 with value: 10.014951705932617.
# [I 2025-05-28 12:04:12,512] Trial 2 finished with value: 27.092082977294922 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.25776143866288703, 'learning_rate': 0.00013549072762894274, 'weight_decay': 2.3338429124208e-05, 'activation': 'relu'}. Best is trial 0 with value: 10.014951705932617.
# [I 2025-05-28 12:04:41,604] Trial 3 finished with value: 28.497268676757812 and parameters: {'num_layers': 3, 'hidden_units': 32, 'dropout': 0.07307223825982118, 'learning_rate': 0.0001440771291655383, 'weight_decay': 5.8924877782782916e-05, 'activation': 'relu'}. Best is trial 0 with value: 10.014951705932617.
# [I 2025-05-28 12:05:41,574] Trial 4 finished with value: 9.2623291015625 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4723144724753571, 'learning_rate': 0.0021773151033911637, 'weight_decay': 1.745937003727837e-05, 'activation': 'relu'}. Best is trial 4 with value: 9.2623291015625.
# [I 2025-05-28 12:06:05,425] Trial 5 finished with value: 26.841997146606445 and parameters: {'num_layers': 2, 'hidden_units': 32, 'dropout': 0.16178610739773425, 'learning_rate': 0.00036648837503529074, 'weight_decay': 0.00018250789959937814, 'activation': 'elu'}. Best is trial 4 with value: 9.2623291015625.
# [I 2025-05-28 12:06:25,491] Trial 6 finished with value: 13.056363105773926 and parameters: {'num_layers': 2, 'hidden_units': 16, 'dropout': 0.19089171928101012, 'learning_rate': 0.0038233374477944122, 'weight_decay': 0.00020934767003955745, 'activation': 'elu'}. Best is trial 4 with value: 9.2623291015625.
# [I 2025-05-28 12:06:51,262] Trial 7 finished with value: 27.620214462280273 and parameters: {'num_layers': 3, 'hidden_units': 16, 'dropout': 0.05401848651909186, 'learning_rate': 0.00034594852292713904, 'weight_decay': 1.0264823897105823e-05, 'activation': 'elu'}. Best is trial 4 with value: 9.2623291015625.
# [I 2025-05-28 12:07:22,667] Trial 8 finished with value: 29.806415557861328 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.2706722889894647, 'learning_rate': 0.00010092361751161856, 'weight_decay': 2.7910854816182156e-05, 'activation': 'elu'}. Best is trial 4 with value: 9.2623291015625.
# [I 2025-05-28 12:07:54,172] Trial 9 finished with value: 10.041788101196289 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.22990593873394505, 'learning_rate': 0.0036747075615556945, 'weight_decay': 6.83417316854098e-05, 'activation': 'relu'}. Best is trial 4 with value: 9.2623291015625.
# [I 2025-05-28 12:09:05,150] Trial 10 finished with value: 8.862048149108887 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.49173695037613985, 'learning_rate': 0.007888011979879036, 'weight_decay': 0.0008524566029754119, 'activation': 'relu'}. Best is trial 10 with value: 8.862048149108887.
# [I 2025-05-28 12:10:01,952] Trial 11 finished with value: 9.015181541442871 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.48319132881180193, 'learning_rate': 0.006424052715743605, 'weight_decay': 0.0008022321813805287, 'activation': 'relu'}. Best is trial 10 with value: 8.862048149108887.
# [I 2025-05-28 12:11:11,342] Trial 12 finished with value: 8.922086715698242 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.3829411572220265, 'learning_rate': 0.007124147250369612, 'weight_decay': 0.0009055815944606384, 'activation': 'relu'}. Best is trial 10 with value: 8.862048149108887.
# [I 2025-05-28 12:11:52,830] Trial 13 finished with value: 8.772588729858398 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.36639689013462406, 'learning_rate': 0.009515542975357678, 'weight_decay': 0.0009272310750404766, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:12:34,253] Trial 14 finished with value: 8.886962890625 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.3494441303071896, 'learning_rate': 0.007636633575058002, 'weight_decay': 0.0004794741795671887, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:13:16,552] Trial 15 finished with value: 8.930526733398438 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.38785386910889375, 'learning_rate': 0.009588457530878872, 'weight_decay': 0.0004292750494983607, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:13:43,337] Trial 16 finished with value: 13.485902786254883 and parameters: {'num_layers': 2, 'hidden_units': 64, 'dropout': 0.33633157381516743, 'learning_rate': 0.0015952709578203443, 'weight_decay': 0.00038026557804798043, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:14:27,350] Trial 17 finished with value: 9.236197471618652 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.42261140642872885, 'learning_rate': 0.003694441265397654, 'weight_decay': 0.00027383515036872143, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:14:55,839] Trial 18 finished with value: 11.91567325592041 and parameters: {'num_layers': 2, 'hidden_units': 64, 'dropout': 0.30284841702521104, 'learning_rate': 0.0023346902976630465, 'weight_decay': 0.0007170365653236566, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:15:30,236] Trial 19 finished with value: 9.173226356506348 and parameters: {'num_layers': 3, 'hidden_units': 32, 'dropout': 0.4274578181760206, 'learning_rate': 0.004909138800586141, 'weight_decay': 0.00014343545065185993, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:16:16,875] Trial 20 finished with value: 12.39609146118164 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.49625690716627185, 'learning_rate': 0.00074090327867952, 'weight_decay': 0.0005705520822293914, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:17:01,269] Trial 21 finished with value: 9.036995887756348 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.34819978704086363, 'learning_rate': 0.008838906676976295, 'weight_decay': 0.00046673602227921725, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:17:44,736] Trial 22 finished with value: 8.9437255859375 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.32200147127634143, 'learning_rate': 0.00553955470761875, 'weight_decay': 0.0009879213155258638, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:18:30,820] Trial 23 finished with value: 8.831474304199219 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.38901808185215325, 'learning_rate': 0.009916745407718327, 'weight_decay': 0.0003012169348881958, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:19:14,916] Trial 24 finished with value: 9.339438438415527 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.416931950129636, 'learning_rate': 0.0026336893827467946, 'weight_decay': 0.00030486866312040935, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:19:42,826] Trial 25 finished with value: 9.19570541381836 and parameters: {'num_layers': 2, 'hidden_units': 64, 'dropout': 0.390162631077295, 'learning_rate': 0.009606430424279036, 'weight_decay': 0.0006126418430703407, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:20:43,233] Trial 26 finished with value: 8.853774070739746 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4360376329008891, 'learning_rate': 0.00481589926957739, 'weight_decay': 0.0003056432518286834, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:21:23,971] Trial 27 finished with value: 8.885574340820312 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.0029558269572667606, 'learning_rate': 0.0049228559984603034, 'weight_decay': 0.00024921261875596656, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:21:54,174] Trial 28 finished with value: 10.105570793151855 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.43862087456874194, 'learning_rate': 0.0033488860916636013, 'weight_decay': 0.00014064371893183033, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:22:30,744] Trial 29 finished with value: 10.171904563903809 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.37594433303522146, 'learning_rate': 0.0012440535783046348, 'weight_decay': 0.0003380699207900923, 'activation': 'elu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:22:59,714] Trial 30 finished with value: 9.642181396484375 and parameters: {'num_layers': 2, 'hidden_units': 64, 'dropout': 0.2879314306738093, 'learning_rate': 0.005422543890879372, 'weight_decay': 8.682291054801592e-05, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:23:56,733] Trial 31 finished with value: 9.080726623535156 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4532689207710191, 'learning_rate': 0.007021948679796807, 'weight_decay': 0.0006591889849271921, 'activation': 'relu'}. Best is trial 13 with value: 8.772588729858398.
# [I 2025-05-28 12:24:55,274] Trial 32 finished with value: 8.67542839050293 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4963986849714598, 'learning_rate': 0.008828385365130849, 'weight_decay': 0.0005941761260129732, 'activation': 'relu'}. Best is trial 32 with value: 8.67542839050293.
# [I 2025-05-28 12:26:08,198] Trial 33 finished with value: 8.890745162963867 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.44988707127969063, 'learning_rate': 0.005579047989307291, 'weight_decay': 0.0005654545075360158, 'activation': 'relu'}. Best is trial 32 with value: 8.67542839050293.
# [I 2025-05-28 12:26:51,838] Trial 34 finished with value: 9.180198669433594 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.4111073057155983, 'learning_rate': 0.004198491494892155, 'weight_decay': 0.00017339959510794117, 'activation': 'relu'}. Best is trial 32 with value: 8.67542839050293.
# [I 2025-05-28 12:27:54,329] Trial 35 finished with value: 8.650674819946289 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.45691534080783774, 'learning_rate': 0.009652375809149837, 'weight_decay': 0.0003245618614521001, 'activation': 'relu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:28:23,349] Trial 36 finished with value: 9.072860717773438 and parameters: {'num_layers': 3, 'hidden_units': 32, 'dropout': 0.466746612758575, 'learning_rate': 0.009759776048929258, 'weight_decay': 0.0004006156162945596, 'activation': 'elu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:29:07,553] Trial 37 finished with value: 11.6054048538208 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.3704335427751584, 'learning_rate': 0.0009183803730928719, 'weight_decay': 4.055671932964461e-05, 'activation': 'relu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:30:15,870] Trial 38 finished with value: 17.764881134033203 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.23107978531990336, 'learning_rate': 0.00022550370591960201, 'weight_decay': 0.00022371231425035045, 'activation': 'elu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:30:54,344] Trial 39 finished with value: 9.764195442199707 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.4664601579814583, 'learning_rate': 0.0028313934161721616, 'weight_decay': 0.0001225668842434222, 'activation': 'relu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:31:17,798] Trial 40 finished with value: 13.124124526977539 and parameters: {'num_layers': 3, 'hidden_units': 16, 'dropout': 0.12937672293197908, 'learning_rate': 0.0017289725068801267, 'weight_decay': 0.0005479138845677717, 'activation': 'elu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:32:24,814] Trial 41 finished with value: 8.836763381958008 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4994162267692159, 'learning_rate': 0.006651981393985096, 'weight_decay': 0.00032301724866853557, 'activation': 'relu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:33:29,933] Trial 42 finished with value: 9.013090133666992 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.492309928813274, 'learning_rate': 0.006626885930655753, 'weight_decay': 0.0001934624523200114, 'activation': 'relu'}. Best is trial 35 with value: 8.650674819946289.
# [I 2025-05-28 12:34:34,080] Trial 43 finished with value: 8.61744499206543 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4090624478469034, 'learning_rate': 0.007845121120103058, 'weight_decay': 0.0007200751230720953, 'activation': 'relu'}. Best is trial 43 with value: 8.61744499206543.
# [I 2025-05-28 12:35:51,524] Trial 44 finished with value: 8.437308311462402 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.41233990896747014, 'learning_rate': 0.009940672678770702, 'weight_decay': 0.0007456811068228533, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:36:52,133] Trial 45 finished with value: 9.044109344482422 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.41274861952759395, 'learning_rate': 0.007908069282732185, 'weight_decay': 0.0007537409333792558, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:37:19,380] Trial 46 finished with value: 9.528665542602539 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.4729866665921995, 'learning_rate': 0.00801837392273656, 'weight_decay': 0.0009413155814489895, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:38:21,287] Trial 47 finished with value: 11.294214248657227 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.3592847636686359, 'learning_rate': 0.0005071358840531265, 'weight_decay': 0.00071992752747651, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:39:21,263] Trial 48 finished with value: 8.948432922363281 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.39906470321695037, 'learning_rate': 0.006183505549543288, 'weight_decay': 0.00048165118360879666, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:40:22,674] Trial 49 finished with value: 8.876513481140137 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.32774711075290713, 'learning_rate': 0.004456543939801286, 'weight_decay': 0.0008382736331714179, 'activation': 'elu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:40:57,355] Trial 50 finished with value: 9.138980865478516 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.4567090563595722, 'learning_rate': 0.0030867324086313866, 'weight_decay': 0.0006604717303772457, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:41:38,842] Trial 51 finished with value: 8.74255084991455 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.4045964253730167, 'learning_rate': 0.0098948223139032, 'weight_decay': 0.0005081776365040284, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:42:37,771] Trial 52 finished with value: 8.911124229431152 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4412219961524516, 'learning_rate': 0.008081421813532521, 'weight_decay': 0.0005199015215064377, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:43:35,118] Trial 53 finished with value: 8.719597816467285 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.40236134188625805, 'learning_rate': 0.00825299564977507, 'weight_decay': 0.0003783267503879854, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:44:50,967] Trial 54 finished with value: 8.821081161499023 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.40223029543961525, 'learning_rate': 0.0059135131107173, 'weight_decay': 0.00044269608895145305, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:45:55,815] Trial 55 finished with value: 8.892831802368164 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.47459409904842226, 'learning_rate': 0.00782964163430701, 'weight_decay': 0.00039564417823072706, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:46:55,936] Trial 56 finished with value: 8.713499069213867 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.4251982434248345, 'learning_rate': 0.007001094576517527, 'weight_decay': 0.0003898902902324531, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:47:24,049] Trial 57 finished with value: 9.272116661071777 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.42933397382331695, 'learning_rate': 0.0072538740525253794, 'weight_decay': 1.3200949401308144e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:48:35,913] Trial 58 finished with value: 8.855901718139648 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1934417521851313, 'learning_rate': 0.00417200318979712, 'weight_decay': 0.00034329567696990296, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:49:36,212] Trial 59 finished with value: 8.680584907531738 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.309227742695508, 'learning_rate': 0.0085759479969192, 'weight_decay': 0.0002479841596760477, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:50:41,911] Trial 60 finished with value: 8.699880599975586 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.3096005237178662, 'learning_rate': 0.006021256633650946, 'weight_decay': 0.0002572949007816735, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:51:58,472] Trial 61 finished with value: 8.656782150268555 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.26609508215867467, 'learning_rate': 0.0061200383915631686, 'weight_decay': 0.00025715917815056913, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:53:10,411] Trial 62 finished with value: 8.796895980834961 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.3073593245845661, 'learning_rate': 0.00579097145211062, 'weight_decay': 0.00024586050770218404, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:54:16,876] Trial 63 finished with value: 8.914633750915527 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.2740198672052986, 'learning_rate': 0.008638388836756076, 'weight_decay': 0.000165951103840241, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:55:23,245] Trial 64 finished with value: 8.599815368652344 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.2547380291848471, 'learning_rate': 0.005016729475416409, 'weight_decay': 0.00021805240266379417, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:56:42,053] Trial 65 finished with value: 9.06148624420166 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.2513302863480699, 'learning_rate': 0.005021554404038661, 'weight_decay': 0.00021325837835394667, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:57:56,635] Trial 66 finished with value: 8.5784330368042 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.19530874484611432, 'learning_rate': 0.008796949314050855, 'weight_decay': 0.00010155618979973382, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 12:59:13,830] Trial 67 finished with value: 8.761373519897461 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1812481231030938, 'learning_rate': 0.003738938128978049, 'weight_decay': 6.731350300165548e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:00:34,325] Trial 68 finished with value: 8.565650939941406 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.12337787915950696, 'learning_rate': 0.006704224027774679, 'weight_decay': 9.335605268212954e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:01:13,700] Trial 69 finished with value: 9.65842056274414 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.1270894281720863, 'learning_rate': 0.0019314961812622227, 'weight_decay': 9.188062086384447e-05, 'activation': 'elu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:02:30,015] Trial 70 finished with value: 8.733040809631348 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.08867919507077288, 'learning_rate': 0.004744074892173033, 'weight_decay': 0.00010849244909043891, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:03:41,069] Trial 71 finished with value: 8.572365760803223 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.22136904334458185, 'learning_rate': 0.006921000796449187, 'weight_decay': 4.801082406475361e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:04:56,450] Trial 72 finished with value: 8.745635986328125 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.22289346999484716, 'learning_rate': 0.007041807500046375, 'weight_decay': 3.913926486864956e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:06:03,319] Trial 73 finished with value: 8.634469985961914 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.21392019763192957, 'learning_rate': 0.005308023772486188, 'weight_decay': 3.979538475653164e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:07:11,946] Trial 74 finished with value: 8.563285827636719 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.20571767600579494, 'learning_rate': 0.005349490572671176, 'weight_decay': 5.1041438942737885e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:08:25,803] Trial 75 finished with value: 9.073390007019043 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.2144278145841776, 'learning_rate': 0.0033698198364150345, 'weight_decay': 3.806240601414144e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:08:53,546] Trial 76 finished with value: 9.708657264709473 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.14679629217332024, 'learning_rate': 0.004188931221004078, 'weight_decay': 4.943696246633251e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:09:57,867] Trial 77 finished with value: 8.651275634765625 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.20290516026387534, 'learning_rate': 0.005135755837813368, 'weight_decay': 7.708949281975765e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:11:15,469] Trial 78 finished with value: 8.662860870361328 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.16895629693554223, 'learning_rate': 0.006777659238447645, 'weight_decay': 4.720030903023611e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:12:35,614] Trial 79 finished with value: 9.000728607177734 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.23330696876539647, 'learning_rate': 0.0023645438891244774, 'weight_decay': 3.185515648897557e-05, 'activation': 'relu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:13:59,058] Trial 80 finished with value: 8.694255828857422 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.24124320431993437, 'learning_rate': 0.005466730962572605, 'weight_decay': 2.3180437936972078e-05, 'activation': 'elu'}. Best is trial 44 with value: 8.437308311462402.
# [I 2025-05-28 13:15:09,359] Trial 81 finished with value: 8.415417671203613 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0964194515676398, 'learning_rate': 0.008931711090642575, 'weight_decay': 5.362081479917039e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:16:16,368] Trial 82 finished with value: 8.556097030639648 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.07868557537986766, 'learning_rate': 0.007362410984194242, 'weight_decay': 5.3783121663200696e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:17:20,496] Trial 83 finished with value: 8.886220932006836 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.08229566053580172, 'learning_rate': 0.007397658681316536, 'weight_decay': 5.689866471304661e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:18:39,056] Trial 84 finished with value: 8.6875638961792 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.04751447223607204, 'learning_rate': 0.008928614979991284, 'weight_decay': 6.10689118252985e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:20:00,911] Trial 85 finished with value: 8.486625671386719 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1048641513746268, 'learning_rate': 0.009996994219217993, 'weight_decay': 7.847945434561181e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:21:07,854] Trial 86 finished with value: 8.860203742980957 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.10275966542200965, 'learning_rate': 0.009063957345707849, 'weight_decay': 7.744215817259024e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:21:46,805] Trial 87 finished with value: 26.560667037963867 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.050851136099758935, 'learning_rate': 0.00023565745325504188, 'weight_decay': 0.00010839390401579468, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:22:48,195] Trial 88 finished with value: 26.434980392456055 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.11196140113400116, 'learning_rate': 0.00010044619836909335, 'weight_decay': 5.4573934796524e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:23:15,122] Trial 89 finished with value: 9.456192016601562 and parameters: {'num_layers': 2, 'hidden_units': 64, 'dropout': 0.02032544904666443, 'learning_rate': 0.006484576953210357, 'weight_decay': 8.114108792134879e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:23:46,489] Trial 90 finished with value: 9.30982494354248 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.1514736559483456, 'learning_rate': 0.009721460975014223, 'weight_decay': 6.843512659291614e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:24:51,451] Trial 91 finished with value: 8.43593692779541 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06008979476484566, 'learning_rate': 0.007209390497668955, 'weight_decay': 4.7933559537993626e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:25:55,634] Trial 92 finished with value: 8.709046363830566 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.07290701448304635, 'learning_rate': 0.007493578069087418, 'weight_decay': 4.67171573597469e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:27:10,839] Trial 93 finished with value: 8.628499031066895 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06362728676994067, 'learning_rate': 0.008645465113447093, 'weight_decay': 3.274757951066861e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:28:22,345] Trial 94 finished with value: 8.77315616607666 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.037816926957551844, 'learning_rate': 0.0063960276878902616, 'weight_decay': 6.291383798796477e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:29:42,161] Trial 95 finished with value: 8.5246000289917 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.09989410892403161, 'learning_rate': 0.007785369350684461, 'weight_decay': 5.0751858570386535e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:30:47,565] Trial 96 finished with value: 8.4296875 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0977434106386021, 'learning_rate': 0.00996297519229165, 'weight_decay': 5.248464563287667e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:31:53,576] Trial 97 finished with value: 9.714617729187012 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.10090415844039066, 'learning_rate': 0.0012966997627242571, 'weight_decay': 5.151929052253873e-05, 'activation': 'relu'}. Best is trial 81 with value: 8.415417671203613.
# [I 2025-05-28 13:33:01,178] Trial 98 finished with value: 8.352514266967773 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.12328041693082344, 'learning_rate': 0.00984075982453595, 'weight_decay': 4.2615308425242436e-05, 'activation': 'elu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:34:17,765] Trial 99 finished with value: 8.840332984924316 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1219671233862935, 'learning_rate': 0.008093120138158362, 'weight_decay': 2.46541915022322e-05, 'activation': 'elu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:35:39,399] Trial 100 finished with value: 8.704760551452637 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.14023683598971914, 'learning_rate': 0.009396095962661388, 'weight_decay': 3.4218481032630385e-05, 'activation': 'elu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:36:41,026] Trial 101 finished with value: 8.944496154785156 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0894624901189863, 'learning_rate': 0.007499610277699815, 'weight_decay': 4.330375680342159e-05, 'activation': 'elu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:37:49,592] Trial 102 finished with value: 8.662402153015137 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.11269447158611179, 'learning_rate': 0.006868534432675194, 'weight_decay': 5.3971396106411637e-05, 'activation': 'elu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:38:50,198] Trial 103 finished with value: 8.749521255493164 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06796809936258462, 'learning_rate': 0.009725242303438715, 'weight_decay': 7.03007945887841e-05, 'activation': 'elu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:40:01,577] Trial 104 finished with value: 8.708888053894043 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.030021448246714655, 'learning_rate': 0.008345130346491696, 'weight_decay': 3.56072004448899e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:41:18,745] Trial 105 finished with value: 10.627623558044434 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.08287825405243411, 'learning_rate': 0.0006440775128370721, 'weight_decay': 3.0147367821224702e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:42:31,093] Trial 106 finished with value: 8.884825706481934 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.09825124637124384, 'learning_rate': 0.005963617643662741, 'weight_decay': 4.600839440305301e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:43:08,229] Trial 107 finished with value: 8.840140342712402 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.1353070391578058, 'learning_rate': 0.007874880391678338, 'weight_decay': 6.069299871228447e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:44:16,764] Trial 108 finished with value: 8.664376258850098 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1651476195034291, 'learning_rate': 0.009850076948851063, 'weight_decay': 2.7016543152102935e-05, 'activation': 'elu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:45:30,579] Trial 109 finished with value: 8.912470817565918 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1154944440063263, 'learning_rate': 0.004512516861772935, 'weight_decay': 4.301652190932411e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:46:01,005] Trial 110 finished with value: 9.132126808166504 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.060222131599931984, 'learning_rate': 0.00657141217254994, 'weight_decay': 0.0001303894289265288, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:47:15,237] Trial 111 finished with value: 8.700167655944824 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.18381153795934593, 'learning_rate': 0.008781202223746435, 'weight_decay': 9.737599999887846e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:48:19,600] Trial 112 finished with value: 8.6302490234375 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.07653434920580773, 'learning_rate': 0.007249309547013886, 'weight_decay': 8.727171864437186e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:49:32,490] Trial 113 finished with value: 8.725614547729492 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.10498370195031637, 'learning_rate': 0.008834968282178862, 'weight_decay': 5.177129024987591e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:50:49,911] Trial 114 finished with value: 8.594797134399414 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1538822720270303, 'learning_rate': 0.009979675981303204, 'weight_decay': 4.30859229118542e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:52:07,114] Trial 115 finished with value: 8.763689041137695 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.17485741360627263, 'learning_rate': 0.007683074816832038, 'weight_decay': 5.7797136346647706e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:53:19,000] Trial 116 finished with value: 8.72469711303711 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0922884593644599, 'learning_rate': 0.005661057513489275, 'weight_decay': 7.217716437447377e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:54:28,700] Trial 117 finished with value: 8.676255226135254 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.12160368095753438, 'learning_rate': 0.008360092585360475, 'weight_decay': 3.59875383372145e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:55:46,618] Trial 118 finished with value: 25.718992233276367 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1397842301866699, 'learning_rate': 0.00011762014153092915, 'weight_decay': 6.507039108508481e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:57:08,775] Trial 119 finished with value: 8.661246299743652 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.20512969303219938, 'learning_rate': 0.00699742477301554, 'weight_decay': 4.9544824805652995e-05, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:58:29,644] Trial 120 finished with value: 8.888373374938965 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.04196478140693576, 'learning_rate': 0.00613472787989307, 'weight_decay': 0.00010651338146099134, 'activation': 'relu'}. Best is trial 98 with value: 8.352514266967773.
# [I 2025-05-28 13:59:48,478] Trial 121 finished with value: 8.33861255645752 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1507780398347278, 'learning_rate': 0.009136733981799275, 'weight_decay': 4.291139762395118e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:01:05,054] Trial 122 finished with value: 8.737320899963379 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.19736034743833253, 'learning_rate': 0.009020099659327215, 'weight_decay': 4.250758494115396e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:02:17,416] Trial 123 finished with value: 8.708908081054688 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.12717709750283512, 'learning_rate': 0.008074132002478309, 'weight_decay': 5.7259756743993635e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:03:32,767] Trial 124 finished with value: 8.517452239990234 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.11011804310441317, 'learning_rate': 0.009130056998208513, 'weight_decay': 8.202465614270659e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:04:55,304] Trial 125 finished with value: 8.969229698181152 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.10979362100553315, 'learning_rate': 0.00743079926518306, 'weight_decay': 8.449751878157567e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:06:09,345] Trial 126 finished with value: 8.79055404663086 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.09306937455597575, 'learning_rate': 0.0091291769525777, 'weight_decay': 7.428091610899436e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:07:30,594] Trial 127 finished with value: 8.582098007202148 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.07911448251436666, 'learning_rate': 0.009998069591958885, 'weight_decay': 0.00011868166506763317, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:08:09,330] Trial 128 finished with value: 8.707860946655273 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.13432061467437492, 'learning_rate': 0.006772863418763241, 'weight_decay': 3.823112163984146e-05, 'activation': 'elu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:08:39,544] Trial 129 finished with value: 9.491301536560059 and parameters: {'num_layers': 2, 'hidden_units': 64, 'dropout': 0.1594746525726808, 'learning_rate': 0.008020570301154798, 'weight_decay': 4.585108157387274e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:09:56,035] Trial 130 finished with value: 8.739561080932617 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06693451426153538, 'learning_rate': 0.0063981424805627275, 'weight_decay': 6.496834118911424e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:11:15,027] Trial 131 finished with value: 8.629096031188965 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.12097262362544846, 'learning_rate': 0.008895841454378876, 'weight_decay': 5.367809868780773e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:12:36,662] Trial 132 finished with value: 8.944193840026855 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.24081361719689862, 'learning_rate': 0.008407372258305377, 'weight_decay': 0.00014973589068037872, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:13:55,097] Trial 133 finished with value: 8.624260902404785 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.09930610238546762, 'learning_rate': 0.007341876257990669, 'weight_decay': 9.200238235648192e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:15:09,511] Trial 134 finished with value: 8.669821739196777 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.21764706442252446, 'learning_rate': 0.008999860166993, 'weight_decay': 1.0641052388798945e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:16:29,788] Trial 135 finished with value: 8.751935958862305 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.1841209442601269, 'learning_rate': 0.007556849978920611, 'weight_decay': 6.227980946678251e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:17:54,284] Trial 136 finished with value: 8.705310821533203 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.05739543085513524, 'learning_rate': 0.00574329900448755, 'weight_decay': 2.0261260504070702e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:18:23,534] Trial 137 finished with value: 9.29788875579834 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.08632979876404184, 'learning_rate': 0.008408974135974528, 'weight_decay': 4.891864751462703e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:19:32,481] Trial 138 finished with value: 8.795602798461914 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.10782737819368948, 'learning_rate': 0.006850040996303305, 'weight_decay': 3.98687495155842e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:20:58,675] Trial 139 finished with value: 8.63886547088623 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.14422659494912843, 'learning_rate': 0.009933867791118175, 'weight_decay': 2.9901703251155166e-05, 'activation': 'elu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:22:11,215] Trial 140 finished with value: 8.444781303405762 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0730080014135263, 'learning_rate': 0.009076718852329989, 'weight_decay': 5.492190908307138e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:23:32,078] Trial 141 finished with value: 8.816954612731934 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.07420988064844537, 'learning_rate': 0.009124758168996884, 'weight_decay': 5.698415068309991e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:24:56,003] Trial 142 finished with value: 8.719630241394043 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.09751426238495561, 'learning_rate': 0.00782895337229038, 'weight_decay': 5.132850648420283e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:26:20,362] Trial 143 finished with value: 8.675878524780273 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.11841805049112558, 'learning_rate': 0.008344095531269068, 'weight_decay': 4.5852882443004744e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:27:39,284] Trial 144 finished with value: 8.507279396057129 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.13087927607313915, 'learning_rate': 0.009323536044748821, 'weight_decay': 7.694777221596476e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:29:01,041] Trial 145 finished with value: 8.667893409729004 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.13128073978340352, 'learning_rate': 0.009982043035757716, 'weight_decay': 8.233895136740412e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:30:21,600] Trial 146 finished with value: 8.791258811950684 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.10748831209998838, 'learning_rate': 0.006397145663153468, 'weight_decay': 7.265155960021563e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:31:39,731] Trial 147 finished with value: 8.921600341796875 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.08125332157730404, 'learning_rate': 0.0073317019767330655, 'weight_decay': 6.685095933498898e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:32:57,858] Trial 148 finished with value: 8.5889253616333 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.05651736729490042, 'learning_rate': 0.009094355911550342, 'weight_decay': 6.060061244012046e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:34:16,814] Trial 149 finished with value: 8.749431610107422 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.08960981632082893, 'learning_rate': 0.007947555028748061, 'weight_decay': 5.455729983249516e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:35:41,360] Trial 150 finished with value: 8.627836227416992 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.15402371969417603, 'learning_rate': 0.00725240767195695, 'weight_decay': 3.61358867761628e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:37:00,210] Trial 151 finished with value: 8.645163536071777 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.11613474989991937, 'learning_rate': 0.009101057043205496, 'weight_decay': 4.3554615241836315e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# [I 2025-05-28 14:38:16,524] Trial 152 finished with value: 8.570535659790039 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06892057547749907, 'learning_rate': 0.008071951870305412, 'weight_decay': 7.797319839619943e-05, 'activation': 'relu'}. Best is trial 121 with value: 8.33861255645752.
# ...
# [I 2025-05-28 22:22:13,311] Trial 150 finished with value: 8.484034538269043 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.33758994247450924, 'learning_rate': 0.009176377971140647, 'weight_decay': 2.8556333533947022e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:25:16,960] Trial 151 finished with value: 8.26530933380127 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.2852140079847982, 'learning_rate': 0.008206696579883257, 'weight_decay': 3.298463416633641e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:28:20,923] Trial 152 finished with value: 8.234148025512695 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.043375451957582495, 'learning_rate': 0.006993130026301905, 'weight_decay': 4.118239153676409e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:31:29,453] Trial 153 finished with value: 9.136533737182617 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.306928535688596, 'learning_rate': 0.0016538945189926528, 'weight_decay': 3.597465454628043e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:34:39,045] Trial 154 finished with value: 8.334809303283691 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.30886600247309304, 'learning_rate': 0.008878704860342309, 'weight_decay': 2.444045441808959e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:37:45,429] Trial 155 finished with value: 8.540926933288574 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.2780605246760718, 'learning_rate': 0.009999500208528259, 'weight_decay': 3.229379029808585e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:40:53,361] Trial 156 finished with value: 8.37307357788086 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.23921447326207776, 'learning_rate': 0.007797797237815631, 'weight_decay': 3.853297188074959e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:43:57,730] Trial 157 finished with value: 8.222051620483398 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.3793833851984996, 'learning_rate': 0.006614446719435926, 'weight_decay': 5.4268044198328174e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:47:04,567] Trial 158 finished with value: 8.45465087890625 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.16285864611426304, 'learning_rate': 0.006171451355625851, 'weight_decay': 2.7841121602230902e-05, 'activation': 'elu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:48:00,287] Trial 159 finished with value: 9.503154754638672 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.03236111578721703, 'learning_rate': 0.002380917026271867, 'weight_decay': 1.961785276707195e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:51:02,178] Trial 160 finished with value: 8.019437789916992 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06530988669705386, 'learning_rate': 0.007375858446595413, 'weight_decay': 3.419573304849179e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:54:08,463] Trial 161 finished with value: 8.171561241149902 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06466145927896746, 'learning_rate': 0.007604812647977082, 'weight_decay': 3.63362731148092e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 22:57:18,531] Trial 162 finished with value: 8.153594970703125 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.05488095337286805, 'learning_rate': 0.008697613576964087, 'weight_decay': 3.062320979924154e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:00:30,141] Trial 163 finished with value: 8.376823425292969 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.07741420364012586, 'learning_rate': 0.007105461460291734, 'weight_decay': 4.3808553551340404e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:03:33,066] Trial 164 finished with value: 7.955562114715576 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.024817582474178868, 'learning_rate': 0.008222823596012728, 'weight_decay': 3.4773510479556684e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:06:31,281] Trial 165 finished with value: 7.827114105224609 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.023932308622829458, 'learning_rate': 0.00819847078001439, 'weight_decay': 2.636457713390018e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:09:31,967] Trial 166 finished with value: 8.186448097229004 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.024172625247406872, 'learning_rate': 0.008208483006370728, 'weight_decay': 3.41753315560844e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:12:32,080] Trial 167 finished with value: 8.161317825317383 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.00852331447200427, 'learning_rate': 0.007802024834105715, 'weight_decay': 2.584091565824062e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:15:32,467] Trial 168 finished with value: 7.903809547424316 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.04251850458538606, 'learning_rate': 0.009194263253554104, 'weight_decay': 2.2200615793805698e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:18:31,082] Trial 169 finished with value: 8.120598793029785 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0470885351492568, 'learning_rate': 0.009278897113629598, 'weight_decay': 2.150485792204423e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:21:40,827] Trial 170 finished with value: 8.210328102111816 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.06908624196685362, 'learning_rate': 0.008644667296176774, 'weight_decay': 1.813267565290335e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:24:41,680] Trial 171 finished with value: 8.091480255126953 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.02577397833287183, 'learning_rate': 0.0071934501285336626, 'weight_decay': 2.72965063730771e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:27:43,912] Trial 172 finished with value: 7.947843074798584 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.019496854273953975, 'learning_rate': 0.008002094447431026, 'weight_decay': 2.365378014240648e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:30:46,671] Trial 173 finished with value: 8.207635879516602 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.03277600506506413, 'learning_rate': 0.008426553650942161, 'weight_decay': 2.2868874898067624e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:33:51,762] Trial 174 finished with value: 8.014469146728516 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.03873825878459845, 'learning_rate': 0.009455242564030185, 'weight_decay': 2.3613781731869628e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:36:55,698] Trial 175 finished with value: 8.093863487243652 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.018553870183703594, 'learning_rate': 0.009647844021334001, 'weight_decay': 2.042827131808367e-05, 'activation': 'relu'}. Best is trial 104 with value: 7.744707107543945.
# [I 2025-05-28 23:39:59,235] Trial 176 finished with value: 7.736380100250244 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0417059867469588, 'learning_rate': 0.009254101750435093, 'weight_decay': 1.633424346348028e-05, 'activation': 'relu'}. Best is trial 176 with value: 7.736380100250244.
# [I 2025-05-28 23:43:01,753] Trial 177 finished with value: 8.163908004760742 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0399819587274152, 'learning_rate': 0.009922141778953229, 'weight_decay': 1.6175838898062938e-05, 'activation': 'relu'}. Best is trial 176 with value: 7.736380100250244.
# [I 2025-05-28 23:46:09,845] Trial 178 finished with value: 8.031370162963867 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0438493120530475, 'learning_rate': 0.00838674696477459, 'weight_decay': 1.5188940664088949e-05, 'activation': 'relu'}. Best is trial 176 with value: 7.736380100250244.
# [I 2025-05-28 23:49:15,702] Trial 179 finished with value: 8.154304504394531 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.05414192371206668, 'learning_rate': 0.007751140741593848, 'weight_decay': 1.862395636118003e-05, 'activation': 'relu'}. Best is trial 176 with value: 7.736380100250244.
# [I 2025-05-28 23:52:21,261] Trial 180 finished with value: 7.636318683624268 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.024560349448039174, 'learning_rate': 0.009996786387592884, 'weight_decay': 2.345218108111075e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-28 23:55:22,985] Trial 181 finished with value: 8.241864204406738 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.025562661697444398, 'learning_rate': 0.009099940333563932, 'weight_decay': 2.3888667888650414e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-28 23:58:25,910] Trial 182 finished with value: 8.258852005004883 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.03477124009391154, 'learning_rate': 0.009879202273657359, 'weight_decay': 2.0775144839041182e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:01:26,508] Trial 183 finished with value: 7.987649440765381 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.006948537985142222, 'learning_rate': 0.008460637321773264, 'weight_decay': 1.7299138683467062e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:04:32,542] Trial 184 finished with value: 8.213775634765625 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.004875177246174488, 'learning_rate': 0.008312536690527712, 'weight_decay': 1.691554487579981e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:07:33,822] Trial 185 finished with value: 8.126107215881348 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.013900473208938488, 'learning_rate': 0.00800570797624461, 'weight_decay': 1.4348436287273982e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:10:35,726] Trial 186 finished with value: 8.170822143554688 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.03746572096466191, 'learning_rate': 0.006613962431109182, 'weight_decay': 2.2249198104045887e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:12:10,532] Trial 187 finished with value: 8.538043975830078 and parameters: {'num_layers': 4, 'hidden_units': 32, 'dropout': 0.027061283677359414, 'learning_rate': 0.008402987761105775, 'weight_decay': 1.878870543439856e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:15:14,264] Trial 188 finished with value: 11.113380432128906 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.0022585806450437437, 'learning_rate': 0.00030868184220601917, 'weight_decay': 2.3796284602073066e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:18:19,504] Trial 189 finished with value: 8.42206859588623 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.04455596536726652, 'learning_rate': 0.00703680926234401, 'weight_decay': 1.712687682566071e-05, 'activation': 'elu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:21:22,897] Trial 190 finished with value: 7.796971321105957 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.014227121379480748, 'learning_rate': 0.009900854599811416, 'weight_decay': 0.000164121810516111, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:24:25,725] Trial 191 finished with value: 8.300671577453613 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.015566407083653179, 'learning_rate': 0.009990470120561859, 'weight_decay': 2.499198366924337e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:27:28,397] Trial 192 finished with value: 8.077461242675781 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.023053610571597487, 'learning_rate': 0.008981449651999443, 'weight_decay': 2.1013849391190057e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:30:34,509] Trial 193 finished with value: 8.032732963562012 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.03436430766094692, 'learning_rate': 0.008762000605009493, 'weight_decay': 1.1791124047062896e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:33:41,161] Trial 194 finished with value: 7.8949103355407715 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.009166002671595015, 'learning_rate': 0.007820327949500248, 'weight_decay': 0.00011098062049603946, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:36:49,355] Trial 195 finished with value: 8.050604820251465 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.00791604361038007, 'learning_rate': 0.007748315338870998, 'weight_decay': 9.806985865365932e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:37:45,546] Trial 196 finished with value: 8.861527442932129 and parameters: {'num_layers': 4, 'hidden_units': 16, 'dropout': 0.01626129542736509, 'learning_rate': 0.005965635813893156, 'weight_decay': 1.5726340718239265e-05, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:40:04,247] Trial 197 finished with value: 8.396892547607422 and parameters: {'num_layers': 3, 'hidden_units': 64, 'dropout': 0.001831819468101679, 'learning_rate': 0.007854831482857991, 'weight_decay': 0.00015723506128824727, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:43:06,975] Trial 198 finished with value: 8.330204963684082 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.012405054586651407, 'learning_rate': 0.006835673278396965, 'weight_decay': 0.0002000739431909348, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# [I 2025-05-29 00:46:13,730] Trial 199 finished with value: 7.875991344451904 and parameters: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.028837812300747202, 'learning_rate': 0.008756107934811838, 'weight_decay': 0.00011200633809311303, 'activation': 'relu'}. Best is trial 180 with value: 7.636318683624268.
# Best GAT2 params: {'num_layers': 4, 'hidden_units': 64, 'dropout': 0.024560349448039174, 'learning_rate': 0.009996786387592884, 'weight_decay': 2.345218108111075e-05, 'activation': 'relu'}
