# %% [markdown]
# ## Environment Setup & Dependencies
#
# Before running any graph-building code, we need to install PyTorch Geometric (PyG) and Optuna.
# This cell:
#
# 1. Installs **Optuna** for hyperparameter tuning.
# 2. Removes any pre-installed PyG packages to avoid version conflicts.
# 3. Installs `torch-scatter`, `torch-sparse`, `torch-cluster` for the current PyTorch version.
# 4. Installs the full `torch-geometric` package from the official PyG GitHub.
#
# > **Note:** Make sure your Colab or local environment’s PyTorch version matches the wheels pulled by these commands.

# %%
import torch

# !pip install optuna -q
# !pip uninstall torch-scatter torch-sparse torch-geometric torch-cluster  --y -q
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-{torch.__version__}.html -q
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-{torch.__version__}.html -q
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-{torch.__version__}.html -q
# !pip install git+https://github.com/pyg-team/pytorch_geometric.git -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 19.0 MB/s eta 0:00:00
# WARNING: Skipping torch-scatter as it is not installed.
# WARNING: Skipping torch-sparse as it is not installed.
# WARNING: Skipping torch-geometric as it is not installed.
# WARNING: Skipping torch-cluster as it is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 105.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 30.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done

# %% [markdown]
# ## 1) Core Imports & Drive Mount
#
# This cell pulls in all the Python libraries used in this notebook:
#
# - **Basic tooling**: `os`, `random`, `pickle`, `numpy`, `pandas`
# - **Spatial & graph**: `geopandas`, `networkx`
# - **Machine learning**: `sklearn` utilities, `torch` & `torch_geometric` for GNNs
# - **Hyperparameter tuning**: `optuna` and its `TPESampler`
# - **Metrics**: `mean_squared_error`
#
# It also mounts your Google Drive at `/content/drive`, so that raw and processed data can be loaded from your Drive folder.

# %%
# ────────────────────────────────────────────────────────────
# 1) Core Imports & Drive Mount
# ────────────────────────────────────────────────────────────
import os
import random
import pickle
import numpy as np
import pandas as pd
import geopandas as gpd
import networkx as nx
import torch
import torch.nn.functional as F
import optuna
from optuna.samplers import TPESampler
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import KFold
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv, GATConv
from sklearn.metrics import mean_squared_error
from collections import Counter

# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Code Block Overview
#
# This code block implements the full SCFL graph‐building and tuning pipeline in five parts:
#
# 1. **Load & Prepare Data**
#    - Read 50 m road‐segment GeoJSON from Google Drive
#    - Reproject to EPSG:28992
#    - Compute segment centroids and stack X/Y into `coords`
#
# 2. **Extract Target & Features**
#    - Set `target_col = 'NO2d'` (annual‐mean NO₂)
#    - Build `feature_cols` by filtering GIS buffer columns (traffic, land‐use, population, etc.)
#    - Assemble `feature_matrix` (NumPy) for similarity calculations
#
# 3. **Build Base Graph**
#    - Initialize `G = nx.Graph()`
#    - Add one node per segment (with its metadata)
#    - Add an edge between segments whose geometries touch
#
# 4. **Detect Outliers**
#    - Label highways vs. local roads by `TRAFMAJOR > 20000`
#    - Define `detect_outliers(G, gdf, ...)` to compute each node’s NO₂ residual vs. 1-hop neighbor mean, then flag those > (MAD × threshold)
#    - Run it to produce `error_segs` and print the count
#
# 5. **Define SCFL Augmentation Function**
#    - `augment_grouped_far_knn(...)` groups features into semantic domains (traffic, residential, etc.)
#    - Selects top-n anchors per domain, normalizes features, finds nearest neighbors by cosine similarity
#    - Filters candidate pairs by `sim_thresh`, `min_dist`, `max_dist`, and `hop_thresh`
#    - Samples up to `per_node_cap` edges per node, caps at `max_edges`
#    - Returns augmented graph `G2` and new edge list
#
# 6. **Define Data-Builder Helper**
#    - `build_data_mask_missing(...)` relabels nodes, standardizes features, and builds a `torch_geometric.data.Data` object
#    - Creates an 80/20 train/test mask over non-NaN NO₂ nodes
#    - Excludes flagged `error_segs` from the training mask
#
# 7. **Specify Feature Groups**
#    - Defines the `groups` dictionary mapping domain names (e.g. “traffic”, “residential”) to their feature column lists
#
# 8. **Define GNN Models & CV Helper**
#    - `GCN` and `GAT` classes: three‐layer graph convolution/attention networks with ReLU/ELU
#    - `cross_val_rmse(G_aug, model_cls, fixed_init, fixed_opt)`: builds data, runs 3-fold CV (50 epochs per fold), returns mean RMSE
#
# 9. **Optuna Tuning for GCN**
#    - Fixed init: `in_c=len(feature_cols)`, `h_c=64`, `out_c=1`; optimizer: `lr=0.00914`, `weight_decay=4.29e-05`
#    - `objective_gcn(trial)`: samples SCFL params (`top_n`, `neighbors`, `sim_thresh`, `min_dist`, `max_dist`, `hop_thresh`, `max_edges`, `per_node_cap`), builds `G_aug`, computes CV RMSE, tracks best RMSE & graph
#    - Run 140 trials (80 startup) via `TPESampler`, minimize RMSE
#    - Print best params/RMSE and pickle `best_graph_gcn` to `outputs/G_gcn_augmented.gpickle`
#
# 10. **Optuna Tuning for GAT**
#     - Fixed init: `in_c=len(feature_cols)`, `h_c=16`, `out_c=1`, `heads=2`; optimizer same as GCN
#     - `objective_gat(trial)`: inherits `top_n` from GCN study, samples remaining SCFL params, builds `G_aug`, computes CV RMSE, tracks best RMSE & graph
#     - Run 140 trials (80 startup) via `TPESampler`, minimize RMSE
#     - Print best params/RMSE and pickle `best_graph_gat` to `outputs/G_gat_augmented.gpickle`
#
# Finally, both best graphs are saved under `outputs/` for downstream use.

# %%
# ────────────────────────────────────────────────────────────
# 1) Load & Prepare Data
# ────────────────────────────────────────────────────────────
fp = '/content/drive/MyDrive/Universiteit Utrecht/Thesis/data/road_network_lufeature.geojson'
gdf = gpd.read_file(fp).to_crs(epsg=28992).reset_index(drop=True)
gdf['centroid'] = gdf.geometry.centroid
coords = np.column_stack([gdf.centroid.x, gdf.centroid.y])

target_col = 'NO2d'
feature_cols = [
    c for c in gdf.columns
    if any(s in c for s in ['AGRI','INDUS','NATUR','PORT','RES','TRANS','URBG','WATER',
                             'POP','EEA','HHOLD','RDL','TLOA','HLOA','MRDL','TMLOA','HMLOA',
                             'TRAF','DINV'])
]
feature_matrix = gdf[feature_cols].to_numpy()

# Build base graph
G = nx.Graph()
sidx = gdf.sindex
for idx, row in gdf.iterrows():
    G.add_node(idx, **row.drop('geometry').to_dict())
for idx, geom in enumerate(gdf.geometry):
    for j in sidx.intersection(geom.bounds):
        if idx != j and geom.touches(gdf.geometry[j]):
            G.add_edge(idx, j)

# Detect outliers
gdf['is_highway'] = gdf['TRAFMAJOR'] > 20000
group_thresh = {True: 9.0, False: 5.0}

def detect_outliers(G, gdf, target_col='NO2d', hop=1):
    nodes = list(G.nodes())
    vals, neigh_means = [], []
    for n in nodes:
        v = gdf.at[n, target_col]
        if pd.isna(v):
            vals.append(np.nan); neigh_means.append(np.nan)
            continue
        sp = nx.single_source_shortest_path_length(G, n, cutoff=hop)
        neigh = [m for m in sp if m != n]
        nbr_vals = gdf.loc[neigh, target_col].dropna().values
        vals.append(v)
        neigh_means.append(np.nan if nbr_vals.size == 0 else nbr_vals.mean())
    vals, neigh_means = np.array(vals), np.array(neigh_means)
    valid = ~np.isnan(vals) & ~np.isnan(neigh_means)
    residuals = vals[valid] - neigh_means[valid]
    valid_nodes = np.array(nodes)[valid]
    med = np.median(residuals)
    mad = np.median(np.abs(residuals - med))
    cutoffs = np.array([group_thresh[gdf.at[n,'is_highway']]*mad for n in valid_nodes])
    return valid_nodes[np.abs(residuals - med) > cutoffs].tolist()

error_segs = detect_outliers(G, gdf)
print(f"⚠️ Detected {len(error_segs)} outlier segments.")

# ────────────────────────────────────────────────────────────
# 2) Augmentation & Data‐builder Helpers
# ────────────────────────────────────────────────────────────
def augment_grouped_far_knn(
    G, gdf, groups, coords, feature_matrix, feature_cols,
    top_n, neighbors, sim_thresh, min_dist, max_dist,
    hop_thresh, max_edges, per_node_cap,
    road_id_col="ROAD_FID", suffix='grp_far_knn'
):
    road_ids = gdf[road_id_col].to_numpy()
    col_to_idx = {c:i for i,c in enumerate(feature_cols)}
    candidates = set()
    for cols in groups.values():
        if any(c not in col_to_idx for c in cols):
            continue
        intensity = gdf[cols].sum(axis=1)
        top_idx = intensity.nlargest(top_n).index.to_numpy()
        if top_idx.size < 2:
            continue
        idxs = [col_to_idx[c] for c in cols]
        subF = feature_matrix[top_idx][:, idxs]
        subF /= np.linalg.norm(subF, axis=1, keepdims=True).clip(1e-6)
        nbr = NearestNeighbors(
            n_neighbors=min(neighbors+1, len(top_idx)),
            metric='cosine', n_jobs=-1
        ).fit(subF)
        dists, nn_idxs = nbr.kneighbors(subF)
        sims = 1 - dists
        for ii, src in enumerate(top_idx):
            close = set(nx.single_source_shortest_path_length(G, int(src), cutoff=hop_thresh))
            for rank, dst_j in enumerate(nn_idxs[ii,1:], start=1):
                if sims[ii, rank] < sim_thresh:
                    break
                dst = top_idx[dst_j]
                u,v = sorted((int(src), int(dst)))
                if road_ids[src] == road_ids[dst]:
                    continue
                dxy = np.hypot(*(coords[src] - coords[dst]))
                if dxy < min_dist or dxy > max_dist or dst in close:
                    continue
                candidates.add((u,v))
    final, counts = [], Counter()
    for u,v in random.sample(list(candidates), len(candidates)):
        if counts[u] < per_node_cap and counts[v] < per_node_cap:
            final.append((u,v))
            counts[u] += 1; counts[v] += 1
        if len(final) >= max_edges:
            break
    G2 = G.copy()
    G2.add_edges_from(final, feature_sim=suffix)
    return G2, final

def build_data_mask_missing(G, gdf, feature_cols, target_col, outliers=None):
    gdf2 = gdf.reset_index(drop=True)
    G2 = nx.relabel_nodes(G, {old:new for new,old in enumerate(gdf.index)})
    X = StandardScaler().fit_transform(gdf2[feature_cols])
    y = gdf2[target_col].values.reshape(-1,1)
    edges = np.array(list(G2.edges())).T
    edge_index = torch.tensor(
        np.concatenate([edges, edges[::-1]], axis=1),
        dtype=torch.long
    )
    data = Data(
        x=torch.tensor(X, dtype=torch.float),
        edge_index=edge_index,
        y=torch.tensor(y, dtype=torch.float)
    )
    valid_idx = np.where(~np.isnan(y.flatten()))[0]
    perm = torch.randperm(len(valid_idx))
    n_train = int(0.8 * len(valid_idx))
    train_idx = valid_idx[perm[:n_train].numpy()]
    test_idx  = valid_idx[perm[n_train:].numpy()]
    train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
    test_mask  = torch.zeros(data.num_nodes, dtype=torch.bool)
    train_mask[train_idx] = True
    test_mask[test_idx] = True
    if outliers is not None:
        train_mask[outliers] = False
    data.train_mask, data.test_mask = train_mask, test_mask
    return data

groups = {
  'industrial':['INDUS_300','INDUS_1000'],
  'residential':['RES_300','RES_1000'],
  'agriculture':['AGRI_300','AGRI_1000'],
  'natural':['NATUR_300','NATUR_1000'],
  'port':['PORT_300','PORT_1000'],
  'urb_built':['URBG_300','URBG_1000'],
  'water':['WATER_300','WATER_1000'],
  'traffic':['TRAFNEAR','TRAFMAJOR'],
  'pop':['POP_300','POP_1000'],
  'population_density':['EEA_300','EEA_1000']
}

# ────────────────────────────────────────────────────────────
# 3) GNN Definitions & 3-Fold CV helper
# ────────────────────────────────────────────────────────────
class GCN(torch.nn.Module):
    def __init__(self, in_c, h_c, out_c):
        super().__init__()
        self.conv1 = GCNConv(in_c,   h_c)
        self.conv2 = GCNConv(h_c,   h_c)
        self.conv3 = GCNConv(h_c, out_c)
    def forward(self, x, e):
        x = F.relu(self.conv1(x,e))
        x = F.relu(self.conv2(x,e))
        return F.relu(self.conv3(x,e))

class GAT(torch.nn.Module):
    def __init__(self, in_c, h_c, out_c, heads=2):
        super().__init__()
        self.g1 = GATConv(in_c,      h_c,   heads=heads)
        self.g2 = GATConv(h_c*heads, h_c,   heads=heads)
        self.g3 = GATConv(h_c*heads, out_c, heads=1, concat=False)
    def forward(self, x, e):
        x = F.elu(self.g1(x,e))
        x = F.elu(self.g2(x,e))
        return self.g3(x,e)

def cross_val_rmse(G_aug, model_cls, fixed_init, fixed_opt):
    data = build_data_mask_missing(G_aug, gdf, feature_cols, target_col, outliers=error_segs)
    y = data.y.numpy().flatten()
    valid = np.where(~np.isnan(y))[0]
    kf = KFold(n_splits=3, shuffle=True, random_state=0)
    rmses = []
    for train_idx, test_idx in kf.split(valid):
        tm = torch.zeros(data.num_nodes, dtype=torch.bool)
        te = torch.zeros(data.num_nodes, dtype=torch.bool)
        tm[valid[train_idx]], te[valid[test_idx]] = True, True
        data.train_mask, data.test_mask = tm, te
        dev = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = model_cls(**fixed_init).to(dev)
        opt   = torch.optim.Adam(model.parameters(), **fixed_opt)
        for _ in range(50):
            model.train(); opt.zero_grad()
            out = model(data.x.to(dev), data.edge_index.to(dev))
            loss = F.mse_loss(out[data.train_mask], data.y[data.train_mask].to(dev))
            loss.backward(); opt.step()
        model.eval()
        with torch.no_grad():
            p = model(data.x.to(dev), data.edge_index.to(dev))[data.test_mask].cpu().numpy()
            t = data.y[data.test_mask].cpu().numpy()
        rmses.append(np.sqrt(mean_squared_error(t, p)))
    return float(np.mean(rmses))

# ────────────────────────────────────────────────────────────
# 4) Optuna for GCN (80 startup, 140 trials)
# ────────────────────────────────────────────────────────────
best_rmse_gcn = float('inf')
best_graph_gcn = None

fixed_gcn_init  = {'in_c': len(feature_cols), 'h_c': 64, 'out_c': 1}
fixed_gcn_optim = {'lr': 0.009136733981799275, 'weight_decay': 4.291139762395118e-05}

def objective_gcn(trial):
    global best_rmse_gcn, best_graph_gcn
    random.seed(trial.number); np.random.seed(trial.number)
    aug = {
        'top_n':        trial.suggest_int('top_n',        500,1500,step=500),
        'neighbors':    trial.suggest_int('neighbors',    10,200,  step=10),
        'sim_thresh':   trial.suggest_float('sim_thresh', 0.95,0.9999),
        'min_dist':     trial.suggest_int('min_dist',     50,500),
        'max_dist':     trial.suggest_int('max_dist',     500,5000,log=True),
        'hop_thresh':   trial.suggest_int('hop_thresh',   1,5),
        'max_edges':    trial.suggest_int('max_edges',    500,5000,step=500),
        'per_node_cap': trial.suggest_int('per_node_cap', 1,10)
    }
    G_aug,_ = augment_grouped_far_knn(
        G, gdf, groups, coords,
        feature_matrix, feature_cols,
        **aug, suffix='gcn_aug'
    )
    rmse = cross_val_rmse(G_aug, GCN, fixed_gcn_init, fixed_gcn_optim)
    if rmse < best_rmse_gcn:
        best_rmse_gcn, best_graph_gcn = rmse, G_aug.copy()
    return rmse

study_gcn = optuna.create_study(
    direction='minimize',
    sampler=TPESampler(n_startup_trials=80)
)
study_gcn.optimize(objective_gcn, n_trials=140)

print("🔍 GCN best params:", study_gcn.best_params)
print("🔍 GCN best RMSE :", best_rmse_gcn)

os.makedirs('outputs', exist_ok=True)
with open('outputs/G_gcn_augmented.gpickle','wb') as f:
    pickle.dump(best_graph_gcn, f)

# ────────────────────────────────────────────────────────────
# 5) Optuna for GAT (reuse GCN's top_n)
# ────────────────────────────────────────────────────────────
best_rmse_gat = float('inf')
best_graph_gat = None

fixed_gat_init  = {'in_c': len(feature_cols), 'h_c': 16, 'out_c': 1, 'heads': 2}
fixed_gat_optim = fixed_gcn_optim

def objective_gat(trial):
    global best_rmse_gat, best_graph_gat
    random.seed(trial.number); np.random.seed(trial.number)
    aug = dict(study_gcn.best_params)
    aug.update({
        'neighbors':    trial.suggest_int('neighbors',    10,200,step=10),
        'sim_thresh':   trial.suggest_float('sim_thresh', 0.95,0.9999),
        'min_dist':     trial.suggest_int('min_dist',     50,500),
        'max_dist':     trial.suggest_int('max_dist',     500,5000,log=True),
        'hop_thresh':   trial.suggest_int('hop_thresh',   1,5),
        'max_edges':    trial.suggest_int('max_edges',    500,5000,step=500),
        'per_node_cap': trial.suggest_int('per_node_cap', 1,10)
    })
    G_aug,_ = augment_grouped_far_knn(
        G, gdf, groups, coords,
        feature_matrix, feature_cols,
        **aug, suffix='gat_aug'
    )
    rmse = cross_val_rmse(G_aug, GAT, fixed_gat_init, fixed_gat_optim)
    if rmse < best_rmse_gat:
        best_rmse_gat, best_graph_gat = rmse, G_aug.copy()
    return rmse

study_gat = optuna.create_study(
    direction='minimize',
    sampler=TPESampler(n_startup_trials=80)
)
study_gat.optimize(objective_gat, n_trials=140)

print("🔍 GAT best params:", study_gat.best_params)
print("🔍 GAT best RMSE :", best_rmse_gat)

with open('outputs/G_gat_augmented.gpickle','wb') as f:
    pickle.dump(best_graph_gat, f)

print("✅ All done – best graphs saved under outputs/")
# Out:
# [I 2025-06-25 09:27:16,826] A new study created in memory with name: no-name-3b100393-51d7-469f-a550-5a7109c65f56
# ⚠️ Detected 2172 outlier segments.
# [I 2025-06-25 09:27:26,117] Trial 0 finished with value: 9.352686432673037 and parameters: {'top_n': 1000, 'neighbors': 40, 'sim_thresh': 0.9650662615265146, 'min_dist': 280, 'max_dist': 597, 'hop_thresh': 2, 'max_edges': 3000, 'per_node_cap': 6}. Best is trial 0 with value: 9.352686432673037.
# [I 2025-06-25 09:27:35,939] Trial 1 finished with value: 9.378615261819787 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9715342842733867, 'min_dist': 54, 'max_dist': 590, 'hop_thresh': 4, 'max_edges': 5000, 'per_node_cap': 5}. Best is trial 0 with value: 9.352686432673037.
# [I 2025-06-25 09:27:43,228] Trial 2 finished with value: 9.414966863575286 and parameters: {'top_n': 1500, 'neighbors': 30, 'sim_thresh': 0.963277739615809, 'min_dist': 64, 'max_dist': 2587, 'hop_thresh': 1, 'max_edges': 3500, 'per_node_cap': 4}. Best is trial 0 with value: 9.352686432673037.
# [I 2025-06-25 09:27:59,180] Trial 3 finished with value: 9.349824060259325 and parameters: {'top_n': 1500, 'neighbors': 130, 'sim_thresh': 0.9692200455318307, 'min_dist': 188, 'max_dist': 1751, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 3 with value: 9.349824060259325.
# [I 2025-06-25 09:28:05,282] Trial 4 finished with value: 9.396772644061285 and parameters: {'top_n': 500, 'neighbors': 110, 'sim_thresh': 0.965123653794047, 'min_dist': 223, 'max_dist': 3021, 'hop_thresh': 3, 'max_edges': 3500, 'per_node_cap': 9}. Best is trial 3 with value: 9.349824060259325.
# [I 2025-06-25 09:28:19,648] Trial 5 finished with value: 9.347110710433732 and parameters: {'top_n': 1000, 'neighbors': 160, 'sim_thresh': 0.9879265104879449, 'min_dist': 449, 'max_dist': 1841, 'hop_thresh': 4, 'max_edges': 4000, 'per_node_cap': 4}. Best is trial 5 with value: 9.347110710433732.
# [I 2025-06-25 09:28:27,879] Trial 6 finished with value: 9.40601975052716 and parameters: {'top_n': 500, 'neighbors': 160, 'sim_thresh': 0.9525175996292279, 'min_dist': 50, 'max_dist': 513, 'hop_thresh': 5, 'max_edges': 4000, 'per_node_cap': 10}. Best is trial 5 with value: 9.347110710433732.
# [I 2025-06-25 09:28:40,839] Trial 7 finished with value: 9.325746424367098 and parameters: {'top_n': 1000, 'neighbors': 150, 'sim_thresh': 0.9659478399897349, 'min_dist': 132, 'max_dist': 2023, 'hop_thresh': 2, 'max_edges': 3000, 'per_node_cap': 9}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:28:48,685] Trial 8 finished with value: 9.341749297499456 and parameters: {'top_n': 500, 'neighbors': 140, 'sim_thresh': 0.9722502666549293, 'min_dist': 248, 'max_dist': 589, 'hop_thresh': 4, 'max_edges': 3000, 'per_node_cap': 3}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:28:57,817] Trial 9 finished with value: 9.400354605211428 and parameters: {'top_n': 500, 'neighbors': 180, 'sim_thresh': 0.9997424609266393, 'min_dist': 190, 'max_dist': 4577, 'hop_thresh': 5, 'max_edges': 3500, 'per_node_cap': 10}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:29:12,340] Trial 10 finished with value: 9.397725435941167 and parameters: {'top_n': 1500, 'neighbors': 150, 'sim_thresh': 0.9806473887926006, 'min_dist': 349, 'max_dist': 3627, 'hop_thresh': 3, 'max_edges': 4500, 'per_node_cap': 10}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:29:24,651] Trial 11 finished with value: 9.440890035430877 and parameters: {'top_n': 1000, 'neighbors': 140, 'sim_thresh': 0.9822494838880347, 'min_dist': 457, 'max_dist': 3078, 'hop_thresh': 5, 'max_edges': 5000, 'per_node_cap': 2}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:29:31,375] Trial 12 finished with value: 9.350029175025876 and parameters: {'top_n': 500, 'neighbors': 90, 'sim_thresh': 0.9987040971015412, 'min_dist': 195, 'max_dist': 746, 'hop_thresh': 1, 'max_edges': 3000, 'per_node_cap': 7}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:29:40,213] Trial 13 finished with value: 9.403662412787414 and parameters: {'top_n': 1000, 'neighbors': 80, 'sim_thresh': 0.9601510343513249, 'min_dist': 146, 'max_dist': 1453, 'hop_thresh': 1, 'max_edges': 4000, 'per_node_cap': 7}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:29:46,773] Trial 14 finished with value: 9.430249295832583 and parameters: {'top_n': 1000, 'neighbors': 30, 'sim_thresh': 0.9805885445476394, 'min_dist': 258, 'max_dist': 823, 'hop_thresh': 4, 'max_edges': 5000, 'per_node_cap': 8}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:29:58,340] Trial 15 finished with value: 9.422552797542687 and parameters: {'top_n': 1500, 'neighbors': 110, 'sim_thresh': 0.9839093965157445, 'min_dist': 486, 'max_dist': 2939, 'hop_thresh': 4, 'max_edges': 4500, 'per_node_cap': 10}. Best is trial 7 with value: 9.325746424367098.
# [I 2025-06-25 09:30:11,210] Trial 16 finished with value: 9.269062742735096 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9521524238844872, 'min_dist': 484, 'max_dist': 1355, 'hop_thresh': 2, 'max_edges': 1500, 'per_node_cap': 9}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:30:19,857] Trial 17 finished with value: 9.289240085149466 and parameters: {'top_n': 1000, 'neighbors': 110, 'sim_thresh': 0.9952030133316387, 'min_dist': 500, 'max_dist': 857, 'hop_thresh': 3, 'max_edges': 1500, 'per_node_cap': 7}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:30:28,707] Trial 18 finished with value: 9.401649659850825 and parameters: {'top_n': 500, 'neighbors': 160, 'sim_thresh': 0.9889315334046659, 'min_dist': 113, 'max_dist': 3668, 'hop_thresh': 1, 'max_edges': 5000, 'per_node_cap': 2}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:30:42,457] Trial 19 finished with value: 9.426764546757443 and parameters: {'top_n': 1000, 'neighbors': 180, 'sim_thresh': 0.982755485030808, 'min_dist': 211, 'max_dist': 3575, 'hop_thresh': 2, 'max_edges': 3000, 'per_node_cap': 8}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:30:48,818] Trial 20 finished with value: 9.340415772862528 and parameters: {'top_n': 500, 'neighbors': 70, 'sim_thresh': 0.9985199903311667, 'min_dist': 52, 'max_dist': 3259, 'hop_thresh': 2, 'max_edges': 3500, 'per_node_cap': 2}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:31:00,331] Trial 21 finished with value: 9.419249023704957 and parameters: {'top_n': 1000, 'neighbors': 130, 'sim_thresh': 0.9847884908333175, 'min_dist': 249, 'max_dist': 3659, 'hop_thresh': 5, 'max_edges': 4000, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:31:09,520] Trial 22 finished with value: 9.333305063278024 and parameters: {'top_n': 500, 'neighbors': 190, 'sim_thresh': 0.9907232283723063, 'min_dist': 486, 'max_dist': 1267, 'hop_thresh': 4, 'max_edges': 2000, 'per_node_cap': 1}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:31:19,349] Trial 23 finished with value: 9.390564644046863 and parameters: {'top_n': 1000, 'neighbors': 140, 'sim_thresh': 0.9585322944120295, 'min_dist': 482, 'max_dist': 946, 'hop_thresh': 1, 'max_edges': 4500, 'per_node_cap': 5}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:31:25,779] Trial 24 finished with value: 9.346945985080128 and parameters: {'top_n': 500, 'neighbors': 50, 'sim_thresh': 0.9925375027619154, 'min_dist': 177, 'max_dist': 1337, 'hop_thresh': 5, 'max_edges': 1500, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:31:39,362] Trial 25 finished with value: 9.284492653770853 and parameters: {'top_n': 1500, 'neighbors': 120, 'sim_thresh': 0.9815162301397077, 'min_dist': 66, 'max_dist': 2612, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:31:50,210] Trial 26 finished with value: 9.316053214231523 and parameters: {'top_n': 1000, 'neighbors': 120, 'sim_thresh': 0.9770815704299955, 'min_dist': 162, 'max_dist': 3143, 'hop_thresh': 1, 'max_edges': 2500, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:32:07,024] Trial 27 finished with value: 9.330611254143717 and parameters: {'top_n': 1500, 'neighbors': 200, 'sim_thresh': 0.9525044230985048, 'min_dist': 359, 'max_dist': 652, 'hop_thresh': 3, 'max_edges': 2500, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:32:13,224] Trial 28 finished with value: 9.525153031483521 and parameters: {'top_n': 1000, 'neighbors': 20, 'sim_thresh': 0.9507616596799171, 'min_dist': 459, 'max_dist': 2455, 'hop_thresh': 3, 'max_edges': 4000, 'per_node_cap': 9}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:32:18,990] Trial 29 finished with value: 9.425040452674315 and parameters: {'top_n': 1500, 'neighbors': 10, 'sim_thresh': 0.9733391367264216, 'min_dist': 172, 'max_dist': 1138, 'hop_thresh': 4, 'max_edges': 5000, 'per_node_cap': 3}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:32:31,446] Trial 30 finished with value: 9.38184526814475 and parameters: {'top_n': 1000, 'neighbors': 160, 'sim_thresh': 0.9661381599310978, 'min_dist': 313, 'max_dist': 2769, 'hop_thresh': 4, 'max_edges': 2500, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:32:41,779] Trial 31 finished with value: 9.4065348857555 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9553133879828581, 'min_dist': 494, 'max_dist': 597, 'hop_thresh': 3, 'max_edges': 3000, 'per_node_cap': 3}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:32:47,611] Trial 32 finished with value: 9.40497586320736 and parameters: {'top_n': 500, 'neighbors': 50, 'sim_thresh': 0.9690951037724304, 'min_dist': 273, 'max_dist': 1290, 'hop_thresh': 5, 'max_edges': 2500, 'per_node_cap': 5}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:32:53,976] Trial 33 finished with value: 9.460594811485493 and parameters: {'top_n': 1500, 'neighbors': 20, 'sim_thresh': 0.9897328886222065, 'min_dist': 365, 'max_dist': 3573, 'hop_thresh': 1, 'max_edges': 3000, 'per_node_cap': 9}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:33:03,124] Trial 34 finished with value: 9.333830035367491 and parameters: {'top_n': 500, 'neighbors': 180, 'sim_thresh': 0.962279593265041, 'min_dist': 433, 'max_dist': 3005, 'hop_thresh': 2, 'max_edges': 3000, 'per_node_cap': 4}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:33:20,866] Trial 35 finished with value: 9.450162470185914 and parameters: {'top_n': 1500, 'neighbors': 200, 'sim_thresh': 0.9809985208669223, 'min_dist': 182, 'max_dist': 1751, 'hop_thresh': 4, 'max_edges': 5000, 'per_node_cap': 8}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:33:28,032] Trial 36 finished with value: 9.317398124416542 and parameters: {'top_n': 500, 'neighbors': 100, 'sim_thresh': 0.9739101953756373, 'min_dist': 456, 'max_dist': 1056, 'hop_thresh': 1, 'max_edges': 1500, 'per_node_cap': 3}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:33:34,370] Trial 37 finished with value: 9.330717693247658 and parameters: {'top_n': 1500, 'neighbors': 20, 'sim_thresh': 0.96567026198857, 'min_dist': 140, 'max_dist': 1601, 'hop_thresh': 1, 'max_edges': 2000, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:33:39,789] Trial 38 finished with value: 9.35610273826876 and parameters: {'top_n': 500, 'neighbors': 40, 'sim_thresh': 0.977679913198209, 'min_dist': 419, 'max_dist': 2245, 'hop_thresh': 1, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:33:45,962] Trial 39 finished with value: 9.398785146732678 and parameters: {'top_n': 500, 'neighbors': 60, 'sim_thresh': 0.9894272342866832, 'min_dist': 347, 'max_dist': 3172, 'hop_thresh': 4, 'max_edges': 3000, 'per_node_cap': 5}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:33:50,981] Trial 40 finished with value: 9.378186388419481 and parameters: {'top_n': 500, 'neighbors': 20, 'sim_thresh': 0.967816486857778, 'min_dist': 459, 'max_dist': 2236, 'hop_thresh': 2, 'max_edges': 2500, 'per_node_cap': 10}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:34:01,642] Trial 41 finished with value: 9.443871010955492 and parameters: {'top_n': 1000, 'neighbors': 120, 'sim_thresh': 0.9808189865129409, 'min_dist': 90, 'max_dist': 564, 'hop_thresh': 5, 'max_edges': 3500, 'per_node_cap': 9}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:34:14,689] Trial 42 finished with value: 9.312483009504666 and parameters: {'top_n': 1000, 'neighbors': 170, 'sim_thresh': 0.9631247079988449, 'min_dist': 306, 'max_dist': 1869, 'hop_thresh': 1, 'max_edges': 1500, 'per_node_cap': 6}. Best is trial 16 with value: 9.269062742735096.
# [I 2025-06-25 09:34:29,671] Trial 43 finished with value: 9.265093341009205 and parameters: {'top_n': 1000, 'neighbors': 190, 'sim_thresh': 0.9977058686691826, 'min_dist': 149, 'max_dist': 2256, 'hop_thresh': 1, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:34:37,632] Trial 44 finished with value: 9.446321191220221 and parameters: {'top_n': 1500, 'neighbors': 60, 'sim_thresh': 0.9737879495609163, 'min_dist': 183, 'max_dist': 2186, 'hop_thresh': 1, 'max_edges': 3000, 'per_node_cap': 2}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:34:45,651] Trial 45 finished with value: 9.362710017995845 and parameters: {'top_n': 1500, 'neighbors': 40, 'sim_thresh': 0.9628133046380825, 'min_dist': 175, 'max_dist': 760, 'hop_thresh': 5, 'max_edges': 3500, 'per_node_cap': 1}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:34:52,351] Trial 46 finished with value: 9.381072716498776 and parameters: {'top_n': 500, 'neighbors': 90, 'sim_thresh': 0.9517118356948553, 'min_dist': 284, 'max_dist': 1811, 'hop_thresh': 3, 'max_edges': 3000, 'per_node_cap': 1}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:35:05,357] Trial 47 finished with value: 9.277567553631409 and parameters: {'top_n': 1000, 'neighbors': 180, 'sim_thresh': 0.9625774926520861, 'min_dist': 366, 'max_dist': 747, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 1}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:35:21,456] Trial 48 finished with value: 9.382250136214848 and parameters: {'top_n': 1500, 'neighbors': 160, 'sim_thresh': 0.9702067493757728, 'min_dist': 251, 'max_dist': 1724, 'hop_thresh': 2, 'max_edges': 3500, 'per_node_cap': 9}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:35:30,125] Trial 49 finished with value: 9.426060734310855 and parameters: {'top_n': 500, 'neighbors': 170, 'sim_thresh': 0.9637443508025981, 'min_dist': 371, 'max_dist': 2473, 'hop_thresh': 4, 'max_edges': 2500, 'per_node_cap': 9}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:35:40,520] Trial 50 finished with value: 9.36231307032428 and parameters: {'top_n': 1000, 'neighbors': 110, 'sim_thresh': 0.9682912633199662, 'min_dist': 238, 'max_dist': 1911, 'hop_thresh': 5, 'max_edges': 4000, 'per_node_cap': 4}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:35:57,656] Trial 51 finished with value: 9.466528366096101 and parameters: {'top_n': 1500, 'neighbors': 200, 'sim_thresh': 0.9570820770603456, 'min_dist': 250, 'max_dist': 827, 'hop_thresh': 3, 'max_edges': 2500, 'per_node_cap': 2}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:36:09,008] Trial 52 finished with value: 9.403904395775873 and parameters: {'top_n': 1000, 'neighbors': 130, 'sim_thresh': 0.9800256628860495, 'min_dist': 145, 'max_dist': 1284, 'hop_thresh': 3, 'max_edges': 4000, 'per_node_cap': 4}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:36:13,737] Trial 53 finished with value: 9.386975578493619 and parameters: {'top_n': 500, 'neighbors': 10, 'sim_thresh': 0.9835059578404498, 'min_dist': 456, 'max_dist': 1240, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 5}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:36:27,390] Trial 54 finished with value: 9.40219569780541 and parameters: {'top_n': 1000, 'neighbors': 190, 'sim_thresh': 0.9863809607393683, 'min_dist': 415, 'max_dist': 1788, 'hop_thresh': 1, 'max_edges': 4000, 'per_node_cap': 4}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:36:36,033] Trial 55 finished with value: 9.343285458265022 and parameters: {'top_n': 500, 'neighbors': 180, 'sim_thresh': 0.9963019933233404, 'min_dist': 413, 'max_dist': 837, 'hop_thresh': 1, 'max_edges': 2000, 'per_node_cap': 4}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:36:46,197] Trial 56 finished with value: 9.35413646702478 and parameters: {'top_n': 1000, 'neighbors': 110, 'sim_thresh': 0.9983979594075835, 'min_dist': 397, 'max_dist': 2234, 'hop_thresh': 1, 'max_edges': 3000, 'per_node_cap': 1}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:37:00,633] Trial 57 finished with value: 9.377065191100282 and parameters: {'top_n': 1500, 'neighbors': 130, 'sim_thresh': 0.9688031740914543, 'min_dist': 201, 'max_dist': 3259, 'hop_thresh': 2, 'max_edges': 4000, 'per_node_cap': 3}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:37:13,270] Trial 58 finished with value: 9.327484172004594 and parameters: {'top_n': 1500, 'neighbors': 110, 'sim_thresh': 0.9914643067871716, 'min_dist': 132, 'max_dist': 1027, 'hop_thresh': 2, 'max_edges': 2500, 'per_node_cap': 1}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:37:17,728] Trial 59 finished with value: 9.281746067571945 and parameters: {'top_n': 500, 'neighbors': 50, 'sim_thresh': 0.9696924848263769, 'min_dist': 160, 'max_dist': 2094, 'hop_thresh': 3, 'max_edges': 1500, 'per_node_cap': 9}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:37:37,085] Trial 60 finished with value: 9.350505496213968 and parameters: {'top_n': 1500, 'neighbors': 190, 'sim_thresh': 0.9956971643060409, 'min_dist': 196, 'max_dist': 2239, 'hop_thresh': 2, 'max_edges': 2000, 'per_node_cap': 8}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:37:50,427] Trial 61 finished with value: 9.427226552762434 and parameters: {'top_n': 1000, 'neighbors': 180, 'sim_thresh': 0.9645321003712568, 'min_dist': 469, 'max_dist': 2803, 'hop_thresh': 2, 'max_edges': 4500, 'per_node_cap': 9}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:37:59,401] Trial 62 finished with value: 9.405604281596235 and parameters: {'top_n': 500, 'neighbors': 180, 'sim_thresh': 0.9730579618375449, 'min_dist': 376, 'max_dist': 3204, 'hop_thresh': 3, 'max_edges': 3000, 'per_node_cap': 5}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:38:05,735] Trial 63 finished with value: 9.328912585094107 and parameters: {'top_n': 1000, 'neighbors': 30, 'sim_thresh': 0.976903950794183, 'min_dist': 115, 'max_dist': 2306, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:38:13,643] Trial 64 finished with value: 9.346021656621062 and parameters: {'top_n': 500, 'neighbors': 140, 'sim_thresh': 0.9787083181693195, 'min_dist': 361, 'max_dist': 1333, 'hop_thresh': 3, 'max_edges': 3000, 'per_node_cap': 10}. Best is trial 43 with value: 9.265093341009205.
# [I 2025-06-25 09:38:25,201] Trial 65 finished with value: 9.26371821191542 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9844226750410412, 'min_dist': 208, 'max_dist': 2659, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 9}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:38:34,245] Trial 66 finished with value: 9.329041807821065 and parameters: {'top_n': 500, 'neighbors': 180, 'sim_thresh': 0.9663284808847645, 'min_dist': 233, 'max_dist': 789, 'hop_thresh': 5, 'max_edges': 3000, 'per_node_cap': 4}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:38:46,674] Trial 67 finished with value: 9.306100930050514 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9616116280930845, 'min_dist': 460, 'max_dist': 4881, 'hop_thresh': 3, 'max_edges': 2000, 'per_node_cap': 10}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:38:50,933] Trial 68 finished with value: 9.460256666287508 and parameters: {'top_n': 500, 'neighbors': 40, 'sim_thresh': 0.9590827459613869, 'min_dist': 220, 'max_dist': 3340, 'hop_thresh': 2, 'max_edges': 2500, 'per_node_cap': 6}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:39:01,575] Trial 69 finished with value: 9.419092037057654 and parameters: {'top_n': 1000, 'neighbors': 120, 'sim_thresh': 0.9648587103076154, 'min_dist': 455, 'max_dist': 530, 'hop_thresh': 2, 'max_edges': 5000, 'per_node_cap': 7}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:39:09,743] Trial 70 finished with value: 9.333677550915118 and parameters: {'top_n': 1000, 'neighbors': 70, 'sim_thresh': 0.9530793660331064, 'min_dist': 111, 'max_dist': 960, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 4}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:39:17,192] Trial 71 finished with value: 9.352158412107078 and parameters: {'top_n': 500, 'neighbors': 110, 'sim_thresh': 0.9730672455502862, 'min_dist': 385, 'max_dist': 3616, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 10}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:39:22,230] Trial 72 finished with value: 9.497612937978152 and parameters: {'top_n': 1000, 'neighbors': 30, 'sim_thresh': 0.975901894736882, 'min_dist': 325, 'max_dist': 2037, 'hop_thresh': 5, 'max_edges': 4500, 'per_node_cap': 9}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:39:30,039] Trial 73 finished with value: 9.375703690943892 and parameters: {'top_n': 500, 'neighbors': 120, 'sim_thresh': 0.9886179951264263, 'min_dist': 290, 'max_dist': 3623, 'hop_thresh': 1, 'max_edges': 3000, 'per_node_cap': 8}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:39:39,146] Trial 74 finished with value: 9.385538231591902 and parameters: {'top_n': 500, 'neighbors': 200, 'sim_thresh': 0.9610016688056979, 'min_dist': 453, 'max_dist': 2237, 'hop_thresh': 1, 'max_edges': 2500, 'per_node_cap': 4}. Best is trial 65 with value: 9.26371821191542.
# [I 2025-06-25 09:39:54,330] Trial 75 finished with value: 9.237863469044317 and parameters: {'top_n': 1500, 'neighbors': 120, 'sim_thresh': 0.9637477108334409, 'min_dist': 209, 'max_dist': 2666, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:40:06,490] Trial 76 finished with value: 9.287946170678406 and parameters: {'top_n': 1500, 'neighbors': 120, 'sim_thresh': 0.9770998420479617, 'min_dist': 385, 'max_dist': 2778, 'hop_thresh': 3, 'max_edges': 1500, 'per_node_cap': 7}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:40:26,151] Trial 77 finished with value: 9.489519076653963 and parameters: {'top_n': 1500, 'neighbors': 200, 'sim_thresh': 0.9948950741955281, 'min_dist': 192, 'max_dist': 3531, 'hop_thresh': 5, 'max_edges': 5000, 'per_node_cap': 7}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:40:36,713] Trial 78 finished with value: 9.402064963245076 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9692336893067256, 'min_dist': 226, 'max_dist': 902, 'hop_thresh': 5, 'max_edges': 5000, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:40:50,609] Trial 79 finished with value: 9.29365921298677 and parameters: {'top_n': 1000, 'neighbors': 190, 'sim_thresh': 0.9876321132648156, 'min_dist': 189, 'max_dist': 1796, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 5}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:41:02,991] Trial 80 finished with value: 9.270256201612504 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9570456434996267, 'min_dist': 86, 'max_dist': 4020, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:41:15,231] Trial 81 finished with value: 9.27999346604534 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.954347762677506, 'min_dist': 64, 'max_dist': 2587, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:41:27,702] Trial 82 finished with value: 9.389687094200035 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9560509839044535, 'min_dist': 85, 'max_dist': 2527, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:41:37,972] Trial 83 finished with value: 9.25270014508849 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9533276966458554, 'min_dist': 70, 'max_dist': 2657, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:41:50,078] Trial 84 finished with value: 9.275237989648543 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9540844998660207, 'min_dist': 66, 'max_dist': 4325, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:42:01,737] Trial 85 finished with value: 9.37361311975828 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9552391535203828, 'min_dist': 67, 'max_dist': 4097, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:42:12,686] Trial 86 finished with value: 9.334685856020185 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9536752285059763, 'min_dist': 94, 'max_dist': 4097, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:42:23,070] Trial 87 finished with value: 9.366753572730849 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9502272596991649, 'min_dist': 73, 'max_dist': 4081, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:42:34,492] Trial 88 finished with value: 9.319433391402791 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.954199597650104, 'min_dist': 51, 'max_dist': 1490, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:42:45,610] Trial 89 finished with value: 9.267633876315067 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.957444943943858, 'min_dist': 106, 'max_dist': 2640, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:42:55,289] Trial 90 finished with value: 9.302220422183668 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9578465899956233, 'min_dist': 100, 'max_dist': 4537, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:43:07,171] Trial 91 finished with value: 9.29463256112893 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9518794750743257, 'min_dist': 76, 'max_dist': 2627, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:43:19,369] Trial 92 finished with value: 9.30702549328665 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9566026196649001, 'min_dist': 60, 'max_dist': 2932, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:43:30,801] Trial 93 finished with value: 9.40003548430053 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9593730220917374, 'min_dist': 120, 'max_dist': 2364, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:43:41,060] Trial 94 finished with value: 9.276199245314318 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9545449243949884, 'min_dist': 100, 'max_dist': 3896, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:43:50,646] Trial 95 finished with value: 9.304478841943197 and parameters: {'top_n': 1500, 'neighbors': 60, 'sim_thresh': 0.9580242316477857, 'min_dist': 101, 'max_dist': 3864, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:44:00,668] Trial 96 finished with value: 9.294095437701657 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9603121885053413, 'min_dist': 156, 'max_dist': 705, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:44:10,362] Trial 97 finished with value: 9.317807806837656 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9512064326940882, 'min_dist': 130, 'max_dist': 4466, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:44:21,074] Trial 98 finished with value: 9.356162534231835 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9552074824058441, 'min_dist': 84, 'max_dist': 4761, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:44:36,807] Trial 99 finished with value: 9.279736546483964 and parameters: {'top_n': 1500, 'neighbors': 150, 'sim_thresh': 0.9575272846087458, 'min_dist': 263, 'max_dist': 2956, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:44:47,636] Trial 100 finished with value: 9.312958480195677 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9528240312831937, 'min_dist': 105, 'max_dist': 3408, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:45:04,901] Trial 101 finished with value: 9.294583959288865 and parameters: {'top_n': 1500, 'neighbors': 170, 'sim_thresh': 0.957458677995415, 'min_dist': 259, 'max_dist': 3001, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:45:16,680] Trial 102 finished with value: 9.332628921558717 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9562029449588354, 'min_dist': 211, 'max_dist': 4368, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:45:26,518] Trial 103 finished with value: 9.295338546649603 and parameters: {'top_n': 1500, 'neighbors': 60, 'sim_thresh': 0.9547153197908755, 'min_dist': 121, 'max_dist': 3901, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:45:41,060] Trial 104 finished with value: 9.281662626714214 and parameters: {'top_n': 1500, 'neighbors': 150, 'sim_thresh': 0.9590366918204866, 'min_dist': 82, 'max_dist': 2676, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:45:57,149] Trial 105 finished with value: 9.27835661841013 and parameters: {'top_n': 1500, 'neighbors': 150, 'sim_thresh': 0.9534329906801037, 'min_dist': 150, 'max_dist': 2384, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:46:08,600] Trial 106 finished with value: 9.37416784441186 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9526036798674404, 'min_dist': 149, 'max_dist': 2451, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 8}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:46:19,319] Trial 107 finished with value: 9.336671617489541 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.950369094141662, 'min_dist': 132, 'max_dist': 1610, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 7}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:46:29,498] Trial 108 finished with value: 9.267970621704333 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9532573268624567, 'min_dist': 92, 'max_dist': 2813, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:46:38,964] Trial 109 finished with value: 9.33117104235366 and parameters: {'top_n': 1500, 'neighbors': 60, 'sim_thresh': 0.9517797808578651, 'min_dist': 168, 'max_dist': 2855, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 75 with value: 9.237863469044317.
# [I 2025-06-25 09:46:50,035] Trial 110 finished with value: 9.236077838789912 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9563231264178355, 'min_dist': 90, 'max_dist': 3827, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:47:00,545] Trial 111 finished with value: 9.321348850783407 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9560197536429726, 'min_dist': 73, 'max_dist': 3846, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:47:09,584] Trial 112 finished with value: 9.266347161378896 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9709663851351195, 'min_dist': 90, 'max_dist': 4300, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:47:20,357] Trial 113 finished with value: 9.36765644694997 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9540796226939419, 'min_dist': 107, 'max_dist': 4987, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:47:29,088] Trial 114 finished with value: 9.278799812801683 and parameters: {'top_n': 1500, 'neighbors': 50, 'sim_thresh': 0.9671034304817282, 'min_dist': 99, 'max_dist': 3094, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:47:40,151] Trial 115 finished with value: 9.358478915783069 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9715271030860135, 'min_dist': 93, 'max_dist': 4355, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:47:49,852] Trial 116 finished with value: 9.281590399315201 and parameters: {'top_n': 1500, 'neighbors': 60, 'sim_thresh': 0.9598857050183108, 'min_dist': 59, 'max_dist': 4740, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 7}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:48:00,316] Trial 117 finished with value: 9.30079118038428 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9557276780523376, 'min_dist': 81, 'max_dist': 3410, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:48:10,044] Trial 118 finished with value: 9.351400236037222 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9514935956291869, 'min_dist': 122, 'max_dist': 4169, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:48:22,855] Trial 119 finished with value: 9.302831065703709 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9751271813165275, 'min_dist': 91, 'max_dist': 3807, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 9}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:48:32,934] Trial 120 finished with value: 9.357347779086053 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9527006005224358, 'min_dist': 71, 'max_dist': 2706, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:48:44,723] Trial 121 finished with value: 9.271173426598448 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.956820280679871, 'min_dist': 110, 'max_dist': 4268, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:48:56,144] Trial 122 finished with value: 9.339599970997902 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9569674950916423, 'min_dist': 109, 'max_dist': 1432, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:49:07,262] Trial 123 finished with value: 9.337640973831736 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9856257320959079, 'min_dist': 139, 'max_dist': 4312, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:49:20,058] Trial 124 finished with value: 9.304393634977837 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9935563707656531, 'min_dist': 50, 'max_dist': 4691, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:49:30,399] Trial 125 finished with value: 9.278594553927524 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9546213064327862, 'min_dist': 89, 'max_dist': 1952, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:49:39,309] Trial 126 finished with value: 9.303145661599812 and parameters: {'top_n': 1500, 'neighbors': 50, 'sim_thresh': 0.9585490295388219, 'min_dist': 78, 'max_dist': 1138, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:49:48,643] Trial 127 finished with value: 9.265233074560513 and parameters: {'top_n': 1500, 'neighbors': 60, 'sim_thresh': 0.9995046933616718, 'min_dist': 64, 'max_dist': 4003, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:49:58,166] Trial 128 finished with value: 9.316590338943728 and parameters: {'top_n': 1500, 'neighbors': 60, 'sim_thresh': 0.9973255161929054, 'min_dist': 61, 'max_dist': 3728, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:50:09,176] Trial 129 finished with value: 9.281020706450795 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9534181259042623, 'min_dist': 69, 'max_dist': 4032, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 110 with value: 9.236077838789912.
# [I 2025-06-25 09:50:21,474] Trial 130 finished with value: 9.220642745613558 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9994085326942802, 'min_dist': 113, 'max_dist': 3430, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:50:33,453] Trial 131 finished with value: 9.273895480453652 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9987020556278108, 'min_dist': 124, 'max_dist': 3514, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:50:44,359] Trial 132 finished with value: 9.277372100754981 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9992753108290866, 'min_dist': 114, 'max_dist': 3414, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:50:56,157] Trial 133 finished with value: 9.259555144685677 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9998906226453895, 'min_dist': 133, 'max_dist': 3254, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:51:06,944] Trial 134 finished with value: 9.290001116590355 and parameters: {'top_n': 1500, 'neighbors': 80, 'sim_thresh': 0.9997849779128679, 'min_dist': 137, 'max_dist': 3215, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:51:17,113] Trial 135 finished with value: 9.323301051700726 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9976958690042652, 'min_dist': 116, 'max_dist': 3109, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:51:30,168] Trial 136 finished with value: 9.29096186209727 and parameters: {'top_n': 1500, 'neighbors': 110, 'sim_thresh': 0.9973080215330375, 'min_dist': 92, 'max_dist': 2851, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:51:41,800] Trial 137 finished with value: 9.295334935711722 and parameters: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9963720882273215, 'min_dist': 107, 'max_dist': 2126, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 9}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:51:50,547] Trial 138 finished with value: 9.321205715546466 and parameters: {'top_n': 1500, 'neighbors': 70, 'sim_thresh': 0.9948391692736124, 'min_dist': 130, 'max_dist': 2692, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 130 with value: 9.220642745613558.
# [I 2025-06-25 09:52:02,915] Trial 139 finished with value: 9.295827718240021 and parameters: {'top_n': 1500, 'neighbors': 100, 'sim_thresh': 0.9998455107938019, 'min_dist': 83, 'max_dist': 2475, 'hop_thresh': 1, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 130 with value: 9.220642745613558.
# 🔍 GCN best params: {'top_n': 1500, 'neighbors': 90, 'sim_thresh': 0.9994085326942802, 'min_dist': 113, 'max_dist': 3430, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}
# 🔍 GCN best RMSE : 9.220642745613558
# [I 2025-06-25 09:52:04,083] A new study created in memory with name: no-name-142de6ae-58a8-4ead-9254-8be218836b90
# [I 2025-06-25 09:52:12,947] Trial 0 finished with value: 9.63631166702234 and parameters: {'neighbors': 20, 'sim_thresh': 0.9547961436429523, 'min_dist': 342, 'max_dist': 3263, 'hop_thresh': 4, 'max_edges': 2000, 'per_node_cap': 4}. Best is trial 0 with value: 9.63631166702234.
# [I 2025-06-25 09:52:30,693] Trial 1 finished with value: 9.64065273154508 and parameters: {'neighbors': 200, 'sim_thresh': 0.9973481986980512, 'min_dist': 96, 'max_dist': 1253, 'hop_thresh': 2, 'max_edges': 1500, 'per_node_cap': 7}. Best is trial 0 with value: 9.63631166702234.
# [I 2025-06-25 09:52:38,321] Trial 2 finished with value: 9.645546111073735 and parameters: {'neighbors': 30, 'sim_thresh': 0.9550878698143159, 'min_dist': 176, 'max_dist': 534, 'hop_thresh': 3, 'max_edges': 2500, 'per_node_cap': 2}. Best is trial 0 with value: 9.63631166702234.
# [I 2025-06-25 09:52:55,735] Trial 3 finished with value: 9.587118049044994 and parameters: {'neighbors': 160, 'sim_thresh': 0.9535810818672652, 'min_dist': 215, 'max_dist': 2611, 'hop_thresh': 1, 'max_edges': 2000, 'per_node_cap': 2}. Best is trial 3 with value: 9.587118049044994.
# [I 2025-06-25 09:53:14,375] Trial 4 finished with value: 9.571792920160368 and parameters: {'neighbors': 160, 'sim_thresh': 0.9736220638080976, 'min_dist': 309, 'max_dist': 1686, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 5}. Best is trial 4 with value: 9.571792920160368.
# [I 2025-06-25 09:53:27,122] Trial 5 finished with value: 9.69622380233342 and parameters: {'neighbors': 130, 'sim_thresh': 0.9646554951462445, 'min_dist': 172, 'max_dist': 945, 'hop_thresh': 1, 'max_edges': 5000, 'per_node_cap': 6}. Best is trial 4 with value: 9.571792920160368.
# [I 2025-06-25 09:53:44,142] Trial 6 finished with value: 9.645383657248528 and parameters: {'neighbors': 160, 'sim_thresh': 0.9551802427588181, 'min_dist': 75, 'max_dist': 981, 'hop_thresh': 4, 'max_edges': 2000, 'per_node_cap': 6}. Best is trial 4 with value: 9.571792920160368.
# [I 2025-06-25 09:53:50,573] Trial 7 finished with value: 9.720737928913875 and parameters: {'neighbors': 10, 'sim_thresh': 0.9639011735245495, 'min_dist': 388, 'max_dist': 4064, 'hop_thresh': 4, 'max_edges': 2500, 'per_node_cap': 10}. Best is trial 4 with value: 9.571792920160368.
# [I 2025-06-25 09:54:01,968] Trial 8 finished with value: 9.566574963587302 and parameters: {'neighbors': 70, 'sim_thresh': 0.9503250555614849, 'min_dist': 234, 'max_dist': 1593, 'hop_thresh': 4, 'max_edges': 2500, 'per_node_cap': 5}. Best is trial 8 with value: 9.566574963587302.
# [I 2025-06-25 09:54:09,888] Trial 9 finished with value: 9.67694365855754 and parameters: {'neighbors': 30, 'sim_thresh': 0.9988156195156027, 'min_dist': 370, 'max_dist': 2232, 'hop_thresh': 3, 'max_edges': 3500, 'per_node_cap': 7}. Best is trial 8 with value: 9.566574963587302.
# [I 2025-06-25 09:54:18,996] Trial 10 finished with value: 9.749853862347395 and parameters: {'neighbors': 70, 'sim_thresh': 0.9842057421659486, 'min_dist': 139, 'max_dist': 1796, 'hop_thresh': 5, 'max_edges': 4000, 'per_node_cap': 9}. Best is trial 8 with value: 9.566574963587302.
# [I 2025-06-25 09:54:39,296] Trial 11 finished with value: 9.565904904599053 and parameters: {'neighbors': 180, 'sim_thresh': 0.9577431101051931, 'min_dist': 247, 'max_dist': 869, 'hop_thresh': 5, 'max_edges': 1000, 'per_node_cap': 6}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:54:46,216] Trial 12 finished with value: 9.702257016445989 and parameters: {'neighbors': 40, 'sim_thresh': 0.9963702431642474, 'min_dist': 478, 'max_dist': 2882, 'hop_thresh': 2, 'max_edges': 1500, 'per_node_cap': 4}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:54:58,757] Trial 13 finished with value: 9.695020854822687 and parameters: {'neighbors': 100, 'sim_thresh': 0.9826703897819064, 'min_dist': 104, 'max_dist': 862, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:55:12,700] Trial 14 finished with value: 9.94453937123403 and parameters: {'neighbors': 120, 'sim_thresh': 0.9613904308328631, 'min_dist': 67, 'max_dist': 1110, 'hop_thresh': 1, 'max_edges': 3000, 'per_node_cap': 10}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:55:24,151] Trial 15 finished with value: 9.653876152677661 and parameters: {'neighbors': 110, 'sim_thresh': 0.9591118546460878, 'min_dist': 402, 'max_dist': 1012, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 10}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:55:39,353] Trial 16 finished with value: 9.596243732179097 and parameters: {'neighbors': 130, 'sim_thresh': 0.9729007654673495, 'min_dist': 167, 'max_dist': 1450, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 1}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:55:47,194] Trial 17 finished with value: 9.741606335682159 and parameters: {'neighbors': 30, 'sim_thresh': 0.9512596320679267, 'min_dist': 307, 'max_dist': 1182, 'hop_thresh': 4, 'max_edges': 4000, 'per_node_cap': 4}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:56:04,022] Trial 18 finished with value: 9.676513556118996 and parameters: {'neighbors': 150, 'sim_thresh': 0.9925030596521112, 'min_dist': 126, 'max_dist': 4679, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 4}. Best is trial 11 with value: 9.565904904599053.
# [I 2025-06-25 09:56:13,436] Trial 19 finished with value: 9.57054074467098 and parameters: {'neighbors': 80, 'sim_thresh': 0.983206116840118, 'min_dist': 454, 'max_dist': 1137, 'hop_thresh': 1, 'max_edges': 1000, 'per_node_cap': 5}. Best is trial 11 with value: 9.565904904599053.
# ...
# [I 2025-06-25 10:10:48,596] Trial 85 finished with value: 9.562603887926114 and parameters: {'neighbors': 200, 'sim_thresh': 0.991216194368233, 'min_dist': 231, 'max_dist': 748, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:11:07,909] Trial 86 finished with value: 9.604013411178293 and parameters: {'neighbors': 200, 'sim_thresh': 0.9980313949773447, 'min_dist': 227, 'max_dist': 748, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:11:19,456] Trial 87 finished with value: 9.539846747893586 and parameters: {'neighbors': 110, 'sim_thresh': 0.9955650972114474, 'min_dist': 126, 'max_dist': 624, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:11:33,123] Trial 88 finished with value: 9.709899042925315 and parameters: {'neighbors': 110, 'sim_thresh': 0.9951826588734771, 'min_dist': 119, 'max_dist': 587, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:11:52,725] Trial 89 finished with value: 9.719870990050277 and parameters: {'neighbors': 200, 'sim_thresh': 0.9905708607664371, 'min_dist': 57, 'max_dist': 781, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:12:05,095] Trial 90 finished with value: 9.605491819928199 and parameters: {'neighbors': 120, 'sim_thresh': 0.9956071245874669, 'min_dist': 82, 'max_dist': 728, 'hop_thresh': 5, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:12:18,041] Trial 91 finished with value: 9.623760719506194 and parameters: {'neighbors': 100, 'sim_thresh': 0.9923669665196417, 'min_dist': 183, 'max_dist': 648, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 6}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:12:31,201] Trial 92 finished with value: 9.660914257889191 and parameters: {'neighbors': 110, 'sim_thresh': 0.9702397572521251, 'min_dist': 136, 'max_dist': 584, 'hop_thresh': 5, 'max_edges': 1000, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:12:49,158] Trial 93 finished with value: 9.534533514737783 and parameters: {'neighbors': 180, 'sim_thresh': 0.9524764482391841, 'min_dist': 229, 'max_dist': 652, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:13:04,833] Trial 94 finished with value: 9.577274384598487 and parameters: {'neighbors': 170, 'sim_thresh': 0.98791706578857, 'min_dist': 228, 'max_dist': 844, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:13:22,909] Trial 95 finished with value: 9.667342790632743 and parameters: {'neighbors': 180, 'sim_thresh': 0.9527592294799383, 'min_dist': 251, 'max_dist': 678, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 9}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:13:41,446] Trial 96 finished with value: 9.575565156871335 and parameters: {'neighbors': 190, 'sim_thresh': 0.9978884648148869, 'min_dist': 193, 'max_dist': 610, 'hop_thresh': 5, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 78 with value: 9.465841811626621.
# [I 2025-06-25 10:14:01,289] Trial 97 finished with value: 9.442920435674381 and parameters: {'neighbors': 200, 'sim_thresh': 0.9914021618445271, 'min_dist': 240, 'max_dist': 501, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:14:16,697] Trial 98 finished with value: 9.660127258253201 and parameters: {'neighbors': 170, 'sim_thresh': 0.9921778056169276, 'min_dist': 241, 'max_dist': 525, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 8}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:14:31,405] Trial 99 finished with value: 9.63866239446849 and parameters: {'neighbors': 140, 'sim_thresh': 0.9998829503408473, 'min_dist': 432, 'max_dist': 552, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 9}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:14:44,383] Trial 100 finished with value: 9.645906213628061 and parameters: {'neighbors': 110, 'sim_thresh': 0.9521879572601382, 'min_dist': 218, 'max_dist': 506, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 8}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:15:03,753] Trial 101 finished with value: 9.56752156201854 and parameters: {'neighbors': 200, 'sim_thresh': 0.9906629957288615, 'min_dist': 259, 'max_dist': 795, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:15:20,325] Trial 102 finished with value: 9.53605214048806 and parameters: {'neighbors': 190, 'sim_thresh': 0.9936497001391419, 'min_dist': 114, 'max_dist': 667, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:15:39,293] Trial 103 finished with value: 9.59203111097601 and parameters: {'neighbors': 190, 'sim_thresh': 0.9938695900309034, 'min_dist': 92, 'max_dist': 609, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:15:57,907] Trial 104 finished with value: 9.552954544915185 and parameters: {'neighbors': 190, 'sim_thresh': 0.9889963538865322, 'min_dist': 66, 'max_dist': 672, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:16:14,305] Trial 105 finished with value: 9.671073003632399 and parameters: {'neighbors': 180, 'sim_thresh': 0.9958970227435888, 'min_dist': 108, 'max_dist': 913, 'hop_thresh': 4, 'max_edges': 1500, 'per_node_cap': 8}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:16:30,526] Trial 106 finished with value: 9.579584712362315 and parameters: {'neighbors': 150, 'sim_thresh': 0.9948791393558347, 'min_dist': 182, 'max_dist': 576, 'hop_thresh': 4, 'max_edges': 1000, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:16:47,845] Trial 107 finished with value: 9.70248719543711 and parameters: {'neighbors': 170, 'sim_thresh': 0.993418864050961, 'min_dist': 61, 'max_dist': 1066, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:17:05,487] Trial 108 finished with value: 9.599152320695294 and parameters: {'neighbors': 180, 'sim_thresh': 0.9847538048798776, 'min_dist': 484, 'max_dist': 540, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:17:17,743] Trial 109 finished with value: 9.566928986536029 and parameters: {'neighbors': 120, 'sim_thresh': 0.997095113790176, 'min_dist': 113, 'max_dist': 642, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:17:36,631] Trial 110 finished with value: 9.579951627048585 and parameters: {'neighbors': 190, 'sim_thresh': 0.9699063247967663, 'min_dist': 76, 'max_dist': 709, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:17:55,792] Trial 111 finished with value: 9.587237756539135 and parameters: {'neighbors': 200, 'sim_thresh': 0.9890722807246621, 'min_dist': 144, 'max_dist': 672, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:18:13,651] Trial 112 finished with value: 9.536389508056244 and parameters: {'neighbors': 190, 'sim_thresh': 0.9564627998144735, 'min_dist': 92, 'max_dist': 3700, 'hop_thresh': 3, 'max_edges': 1500, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:18:32,961] Trial 113 finished with value: 9.58201673596198 and parameters: {'neighbors': 180, 'sim_thresh': 0.9914530587343919, 'min_dist': 97, 'max_dist': 3621, 'hop_thresh': 3, 'max_edges': 1500, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:18:52,497] Trial 114 finished with value: 9.592393527127859 and parameters: {'neighbors': 190, 'sim_thresh': 0.9574148517717971, 'min_dist': 90, 'max_dist': 3053, 'hop_thresh': 3, 'max_edges': 1500, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:19:10,950] Trial 115 finished with value: 9.628149880511968 and parameters: {'neighbors': 200, 'sim_thresh': 0.9553272549475266, 'min_dist': 129, 'max_dist': 3717, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:19:26,494] Trial 116 finished with value: 9.638593568314837 and parameters: {'neighbors': 130, 'sim_thresh': 0.9500544573468174, 'min_dist': 70, 'max_dist': 3213, 'hop_thresh': 3, 'max_edges': 1500, 'per_node_cap': 9}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:19:45,372] Trial 117 finished with value: 9.58466929046949 and parameters: {'neighbors': 190, 'sim_thresh': 0.952958731693858, 'min_dist': 217, 'max_dist': 2019, 'hop_thresh': 3, 'max_edges': 500, 'per_node_cap': 8}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:20:01,806] Trial 118 finished with value: 9.624706135395387 and parameters: {'neighbors': 170, 'sim_thresh': 0.9985904899580587, 'min_dist': 51, 'max_dist': 3934, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:20:20,641] Trial 119 finished with value: 9.557129686224732 and parameters: {'neighbors': 190, 'sim_thresh': 0.9565960219192854, 'min_dist': 115, 'max_dist': 563, 'hop_thresh': 4, 'max_edges': 500, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:20:39,488] Trial 120 finished with value: 9.646331164892745 and parameters: {'neighbors': 200, 'sim_thresh': 0.986990069081653, 'min_dist': 378, 'max_dist': 501, 'hop_thresh': 5, 'max_edges': 1500, 'per_node_cap': 7}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:20:58,046] Trial 121 finished with value: 9.664762569623472 and parameters: {'neighbors': 190, 'sim_thresh': 0.9898052026682339, 'min_dist': 66, 'max_dist': 593, 'hop_thresh': 3, 'max_edges': 1000, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:21:13,968] Trial 122 finished with value: 9.533106813429043 and parameters: {'neighbors': 180, 'sim_thresh': 0.9929701378904409, 'min_dist': 76, 'max_dist': 673, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:21:32,220] Trial 123 finished with value: 9.686988507553268 and parameters: {'neighbors': 180, 'sim_thresh': 0.9920195199762027, 'min_dist': 78, 'max_dist': 641, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 6}. Best is trial 97 with value: 9.442920435674381.
# [I 2025-06-25 10:21:50,470] Trial 124 finished with value: 9.39702667166012 and parameters: {'neighbors': 180, 'sim_thresh': 0.9929976273907586, 'min_dist': 263, 'max_dist': 726, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:22:08,349] Trial 125 finished with value: 9.508495418798015 and parameters: {'neighbors': 180, 'sim_thresh': 0.9963402178754762, 'min_dist': 85, 'max_dist': 771, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:22:24,399] Trial 126 finished with value: 9.736663777686655 and parameters: {'neighbors': 180, 'sim_thresh': 0.9943513306894025, 'min_dist': 262, 'max_dist': 841, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:22:41,186] Trial 127 finished with value: 9.567263457299774 and parameters: {'neighbors': 160, 'sim_thresh': 0.9998923684720571, 'min_dist': 89, 'max_dist': 1513, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:22:58,057] Trial 128 finished with value: 9.712016398086318 and parameters: {'neighbors': 170, 'sim_thresh': 0.9927971709852683, 'min_dist': 319, 'max_dist': 762, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:23:15,946] Trial 129 finished with value: 9.611519019272844 and parameters: {'neighbors': 180, 'sim_thresh': 0.9971130394064044, 'min_dist': 60, 'max_dist': 704, 'hop_thresh': 2, 'max_edges': 2500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:23:32,196] Trial 130 finished with value: 9.525551303833922 and parameters: {'neighbors': 180, 'sim_thresh': 0.9964023052433033, 'min_dist': 74, 'max_dist': 813, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:23:50,633] Trial 131 finished with value: 9.517819958550016 and parameters: {'neighbors': 180, 'sim_thresh': 0.996561081935117, 'min_dist': 77, 'max_dist': 962, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:24:08,044] Trial 132 finished with value: 9.575770585344776 and parameters: {'neighbors': 170, 'sim_thresh': 0.9967020042753114, 'min_dist': 50, 'max_dist': 814, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:24:24,164] Trial 133 finished with value: 9.60774161336897 and parameters: {'neighbors': 180, 'sim_thresh': 0.9932984080970538, 'min_dist': 76, 'max_dist': 867, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 4}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:24:42,396] Trial 134 finished with value: 9.603939402595238 and parameters: {'neighbors': 180, 'sim_thresh': 0.9961930476011467, 'min_dist': 84, 'max_dist': 726, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:24:59,462] Trial 135 finished with value: 9.60364872035531 and parameters: {'neighbors': 170, 'sim_thresh': 0.9982927266530874, 'min_dist': 241, 'max_dist': 782, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:25:15,637] Trial 136 finished with value: 9.73811851975978 and parameters: {'neighbors': 180, 'sim_thresh': 0.9947909770776912, 'min_dist': 103, 'max_dist': 956, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:25:34,372] Trial 137 finished with value: 9.572744135454675 and parameters: {'neighbors': 190, 'sim_thresh': 0.9971875989184286, 'min_dist': 74, 'max_dist': 672, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 4}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:25:51,760] Trial 138 finished with value: 9.552762054169273 and parameters: {'neighbors': 170, 'sim_thresh': 0.99900473285528, 'min_dist': 66, 'max_dist': 918, 'hop_thresh': 2, 'max_edges': 1000, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# [I 2025-06-25 10:26:08,565] Trial 139 finished with value: 9.648569919025805 and parameters: {'neighbors': 190, 'sim_thresh': 0.9958366951204569, 'min_dist': 94, 'max_dist': 738, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}. Best is trial 124 with value: 9.39702667166012.
# 🔍 GAT best params: {'neighbors': 180, 'sim_thresh': 0.9929976273907586, 'min_dist': 263, 'max_dist': 726, 'hop_thresh': 2, 'max_edges': 500, 'per_node_cap': 5}
# 🔍 GAT best RMSE : 9.39702667166012
# ✅ All done – best graphs saved under outputs/
